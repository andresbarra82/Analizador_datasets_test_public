# %% [markdown]
# # Módulo calidad_datos - LEILA
# Este libro de Jupyter contiene ejemplos con explicaciones de cómo utilizar el módulo que presenta métricas de calidad y descriptivas para conjuntos de datos estructurados

# %%
# Se importar la clase CalidadDatos del módulo calidad_datos

import pandas as pd
import numpy as np

# %% [markdown]
# #### Se importan los csvs

# %%
# se importan los csvs

df = pd.read_csv('C:\\Users\\20927322707\\Desktop\\analizador_datasets\\csv\\actuaciones-fiscalizacion\\contribuyentes-bajo-inspeccion-3-trimestre-2015.csv', sep=',', encoding='utf-8')

# %%
# se visualizan las principales características del dataset , como su metadata y la completitud y calidad de los datos

print("-------------------------")
print("Infomración principal del dataset")
print("-------------------------")
print(df.info())

# calcular la completitud de los datos

completitud_df = df.count() / len(df) * 100
completitud_df = completitud_df.sort_values(ascending=False)

print("-------------------------")
print("Completitud de los datos")
print("-------------------------")
print(completitud_df)


print("-------------------------")
print("Estas son las dimensiones del dataset")
print("-------------------------")
print("Filas: {}".format(df.shape[0]))
print("Columnas: {}".format(df.shape[1]))
print("-------------------------")
# print("Estas son las estadisticas del dataset")
# print(df.describe())
print("-------------------------")
print("Primeras 5 filas del dataset")
print("-------------------------")
print(df.head(5))
print("-------------------------")
print("Estas son las filas duplicadas del dataset")
print("-------------------------")
print(df.duplicated().sum())    
print("-------------------------")
print("Valores unicos")
print("-------------------------")
print(df.nunique())
print("-------------------------")  
print("Valores nulos")    
print("-------------------------")
print(df.isna().sum())
print("-------------------------")
print("Tipos de datos")
print("-------------------------")
print(df.dtypes)


if df.select_dtypes(include=['object']).shape[1] > 0:
    print("El dataset contiene variables categóricas")
    print("-------------------------") 
    print("Variables categóricas")
    print("-------------------------")
    print(df.select_dtypes(include=['object']).columns)
    print("-------------------------")
    print("Valores únicos de las variables categóricas")
    print("-------------------------")
    print(df.select_dtypes(include=['object']).nunique())

else:
    print("El dataset no contiene variables categóricas")


valores_unicos_categoricos =  df.select_dtypes(include=['object']).nunique()

print("-------------------------")
print("Valores únicos de las variables categóricas")
print("-------------------------")
print(valores_unicos_categoricos)
# Out:
# -------------------------
# Infomración principal del dataset
# -------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NUM_ORDEN           1945 non-null   int64
#  1   DEPARTAMENTO        1945 non-null   object
#  2   DIVISION            1669 non-null   object
#  3   INSPECTOR           1945 non-null   object
#  4   SUPERVISOR          1935 non-null   object
#  5   CUIT                1945 non-null   object
#  6   RAZON_SOCIAL        1945 non-null   object
#  7   FECHA_INICIO        1936 non-null   object
#  8   FECHA_DEVOL_TRANSF  277 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 136.9+ KB
# None
# -------------------------
# Completitud de los datos
# -------------------------
# NUM_ORDEN             100.000000
# DEPARTAMENTO          100.000000
# INSPECTOR             100.000000
# CUIT                  100.000000
# RAZON_SOCIAL          100.000000
# FECHA_INICIO           99.537275
# SUPERVISOR             99.485861
# DIVISION               85.809769
# FECHA_DEVOL_TRANSF     14.241645
# dtype: float64
# -------------------------
# Estas son las dimensiones del dataset
# -------------------------
# Filas: 1945
# Columnas: 9
# -------------------------
# -------------------------
# Primeras 5 filas del dataset
# -------------------------
#    NUM_ORDEN                                   DEPARTAMENTO DIVISION  \
# 0          1                                      EXTERNA E        I
# 1          2  PUBLICIDAD, REG. SIMPL. DEL ISIB Y OPERATIVOS        B
# 2          3                                      EXTERNA D   SELLOS
# 3          4                                      EXTERNA B        5
# 4          5                                      EXTERNA A        2
#
#               INSPECTOR         SUPERVISOR         CUIT  \
# 0          CRESPO ARIEL      PATANE ALICIA  30710240244
# 1       CARDONE MARIANO  ZOCCALI JOSE LUIS  33707083129
# 2       LANFRANCO PABLO       ALFARO NADIA  30529994393
# 3  SICILIANO MARIA ROSA      CAPUTO ROMINA  30708826568
# 4       PERALTA MARCELA     ALVAREZ MARTIN  30708449853
#
#                            RAZON_SOCIAL FECHA_INICIO FECHA_DEVOL_TRANSF
# 0                        1001 FARDO SRL   01/10/2014                NaN
# 1                           25 HORAS SA   27/03/2015                NaN
# 2                  3M ARGENTINA SACIFIA   23/12/2013         19/08/2015
# 3  4 M SOCIEDAD DE RESPONSABILIDAD LTDA          N/L                NaN
# 4                       5TH ESSENCE S.A   09/02/2015                NaN
# -------------------------
# Estas son las filas duplicadas del dataset
# -------------------------
# 0
# -------------------------
# Valores unicos
# -------------------------
# NUM_ORDEN             1945
# DEPARTAMENTO            12
# DIVISION                20
# INSPECTOR              319
# SUPERVISOR              65
# CUIT                  1928
# RAZON_SOCIAL          1938
# FECHA_INICIO           499
# FECHA_DEVOL_TRANSF     147
# dtype: int64
# -------------------------
# Valores nulos
# -------------------------
# NUM_ORDEN                0
# DEPARTAMENTO             0
# DIVISION               276
# INSPECTOR                0
# SUPERVISOR              10
# CUIT                     0
# RAZON_SOCIAL             0
# FECHA_INICIO             9
# FECHA_DEVOL_TRANSF    1668
# dtype: int64
# -------------------------
# Tipos de datos
# -------------------------
# NUM_ORDEN              int64
# DEPARTAMENTO          object
# DIVISION              object
# INSPECTOR             object
# SUPERVISOR            object
# CUIT                  object
# RAZON_SOCIAL          object
# FECHA_INICIO          object
# FECHA_DEVOL_TRANSF    object
# dtype: object
# El dataset contiene variables categóricas
# -------------------------
# Variables categóricas
# -------------------------
# Index(['DEPARTAMENTO', 'DIVISION', 'INSPECTOR', 'SUPERVISOR', 'CUIT',
#        'RAZON_SOCIAL', 'FECHA_INICIO', 'FECHA_DEVOL_TRANSF'],
#       dtype='object')
# -------------------------
# Valores únicos de las variables categóricas
# -------------------------
# DEPARTAMENTO            12
# DIVISION                20
# INSPECTOR              319
# SUPERVISOR              65
# CUIT                  1928
# RAZON_SOCIAL          1938
# FECHA_INICIO           499
# FECHA_DEVOL_TRANSF     147
# dtype: int64
# -------------------------
# Valores únicos de las variables categóricas
# -------------------------
# DEPARTAMENTO            12
# DIVISION                20
# INSPECTOR              319
# SUPERVISOR              65
# CUIT                  1928
# RAZON_SOCIAL          1938
# FECHA_INICIO           499
# FECHA_DEVOL_TRANSF     147
# dtype: int64

# %%
import pandas as pd
import numpy as np 

# Obtener los valores únicos de las variables categóricas

# Seleccionar las variables categóricas

valores_categoricos = df.select_dtypes(include=['object'])  # Seleccionar las variables categóricas

print(valores_categoricos)

valores_categoricos = pd.DataFrame(valores_categoricos) # Convertir las variables categóricas en un DataFrame

valores_categoricos_dataframe = valores_categoricos.nunique()

print(valores_categoricos_dataframe)
# Out:
#                                        DEPARTAMENTO DIVISION  \
# 0                                         EXTERNA E        I
# 1     PUBLICIDAD, REG. SIMPL. DEL ISIB Y OPERATIVOS        B
# 2                                         EXTERNA D   SELLOS
# 3                                         EXTERNA B        5
# 4                                         EXTERNA A        2
# ...                                             ...      ...
# 1940                           CONCURSOS Y QUIEBRAS      NaN
# 1941                                      EXTERNA E        I
# 1942                                     OPERATIVOS        A
# 1943                                      EXTERNA D   SELLOS
# 1944                                      EXTERNA C        8
#
#                  INSPECTOR           SUPERVISOR           CUIT  \
# 0             CRESPO ARIEL        PATANE ALICIA    30710240244
# 1          CARDONE MARIANO    ZOCCALI JOSE LUIS    33707083129
# 2          LANFRANCO PABLO         ALFARO NADIA    30529994393
# 3     SICILIANO MARIA ROSA        CAPUTO ROMINA    30708826568
# 4          PERALTA MARCELA       ALVAREZ MARTIN    30708449853
# ...                    ...                  ...            ...
# 1940        CRISPINO PAULO    GIAMMARCHE DANIEL  30-65461789-5
# 1941         IBARRA CARLOS       FERNANDEZ JUAN  30-68077909-7
# 1942     ROUSSEAUX JULIETA       GONZALEZ MAURO  27-18874058-3
# 1943       LANFRANCO PABLO         ALFARO NADIA  30-69102170-6
# 1944         BAREIRO JUANA  SANCHEZ ARIAS HILDA  20-94161034-0
#
#                               RAZON_SOCIAL FECHA_INICIO FECHA_DEVOL_TRANSF
# 0                           1001 FARDO SRL   01/10/2014                NaN
# 1                              25 HORAS SA   27/03/2015                NaN
# 2                     3M ARGENTINA SACIFIA   23/12/2013         19/08/2015
# 3     4 M SOCIEDAD DE RESPONSABILIDAD LTDA          N/L                NaN
# 4                          5TH ESSENCE S.A   09/02/2015                NaN
# ...                                    ...          ...                ...
# 1940              WORLD COLOR ARGENTINA SA   05/06/2015                NaN
# 1941                         WORLD GIFT SA   31/10/2014                NaN
# 1942                            WU YU LING   23/04/2015                NaN
# 1943                      WUNDER PHARM SRL   15/01/2015                NaN
# 1944                            XIA JINHUA   28/04/2015                NaN
#
# [1945 rows x 8 columns]
# DEPARTAMENTO            12
# DIVISION                20
# INSPECTOR              319
# SUPERVISOR              65
# CUIT                  1928
# RAZON_SOCIAL          1938
# FECHA_INICIO           499
# FECHA_DEVOL_TRANSF     147
# dtype: int64

# %%
import pandas as pd
import json

# Obtener los valores únicos de las variables categóricas

valores_unicos_por_categoria = {
    "valores_unicos": {
        columna: df[columna].unique().tolist()
        for columna in df.select_dtypes(include=['object'])
    }
}

with open('valores_unicos_contribuyentes', 'w') as f:      # Abrir un archivo JSON para guardar los valores únicos 'w' es para escribir with es para abrir y cerrar el archivo
    json.dump(valores_unicos_por_categoria, f, indent=4) # Guardar los valores únicos en un archivo JSON donde f es el archivo indent es la identación y dump es para guardar

valores_unicos_por_categoria
# Out:
# {'valores_unicos': {'DEPARTAMENTO': ['EXTERNA E',
#    'PUBLICIDAD, REG. SIMPL. DEL ISIB Y OPERATIVOS',
#    'EXTERNA D',
#    'EXTERNA B',
#    'EXTERNA A',
#    'EXTERNA C',
#    'EXTERNA F',
#    'CONCURSOS Y QUIEBRAS',
#    'OPERATIVOS',
#    'PLANIFICACION Y SELECCION',
#    'NORMAS Y MANUALES DE FISCALIZACION',
#    'BANCOS'],
#   'DIVISION': ['I',
#    'B',
#    'SELLOS',
#    '5',
#    '2',
#    '7',
#    '6',
#    '10',
#    '8',
#    '1',
#    nan,
#    'A',
#    '3',
#    '4',
#    'INTERNA I',
#    '9',
#    'MODULARES SELLOS',
#    'II',
#    'INTERNA II',
#    'EQUIPO A',
#    'BANCOS'],
#   'INSPECTOR': ['CRESPO ARIEL',
#    'CARDONE MARIANO',
#    'LANFRANCO PABLO',
#    'SICILIANO MARIA ROSA',
#    'PERALTA MARCELA',
#    'BERNALDO DE QUIROS ALVARO',
#    'CODERCH ROCHE TATIANA',
#    'RUA, CLAUDIA',
#    'VALDES DAMIAN JAVIER',
#    'SANTORO MARTIN',
#    'PEDRO ROMINA',
#    'IBARRA CARLOS',
#    'ROJAS LORENA',
#    'RIPOLI JORGE',
#    'BODNER ALEJANDRA',
#    'ANDREU DANIEL',
#    'ABBEDUTO JUAN JOSE',
#    'NOVOA NANCY',
#    'IGLESIAS LILIANA',
#    'MOYA JULIETA ANDREA',
#    'PEREIRA VIVIANA',
#    'SANTORO NESTOR',
#    'CASSIS CLAUDIA',
#    'FERRETTI CLAUDIA',
#    'LIPARI GLADYS',
#    'VILLEGAS CESAR',
#    'KARIN EDUARDO DANIEL',
#    'GODINO RUBEN',
#    'SUEIRO FERNANDO',
#    'FORTE M. FLORENCIA',
#    'JULIO MARIANA',
#    'BUJANDA ROMINA',
#    'CASTILLO CAROLINA',
#    'NOVOA MARIANA',
#    'RIVAS GRACIELA',
#    'MARI CRISTIAN',
#    'ORTUBIA MABEL',
#    'ERMILIO MARIA',
#    'CIOCCA ELEONORA',
#    'RODRIGUEZ, MONICA',
#    'GUEVARA LIA',
#    'RIVEIRA SERGIO',
#    'SALMON SILVANA',
#    'LOPEZ MARIA CAROLINA',
#    'ROUSSEAUX JULIETA',
#    'BURGOS ROSA M.',
#    'AVALLONE MARIA LAURA',
#    'LA VALLE MAURICIO',
#    'ORTIZ BROSSARD IVANNA',
#    'NIEMES GUILLERMO',
#    'CALZONE ALEJANDRA',
#    'COLOM SILVIA',
#    'GARCIA LAURA',
#    'YOCCO ELIDA ALICIA',
#    'BOGO MORALES MARIANO',
#    'MUNIZ CLAUDIO',
#    'QUIROGA MARIA FLORENCIA',
#    'ALSAMORA ALBERTO',
#    'BASUALDO MARCELA',
#    'PETRONE MARIA',
#    'MOURELLE LAURA BEATRIZ',
#    'ACHAGA PAOLA',
#    'USAI GABRIELA',
#    'DAGLIO DANIELA',
#    'MALAGUEÑO, ELDA A.',
#    'MAGNO ANALIA PAULA',
#    'CHIUSANO SERGIO',
#    'NAVARRO LAURA',
#    'VAZQUEZ CLAUDIO',
#    'STABILE ALEJANDRO',
#    'DOMINGUEZ MARIA LUZ',
#    'ANDRADA ELEONORA',
#    "D'ANTUONO OSVALDO",
#    'KOLINSKI LAURA',
#    'BUTTAFUOCO, CESAR',
#    'MARINO VIRGINIA',
#    'ZALAZAR KARINA',
#    'CONTRERAS MANUEL',
#    'GRANDE GABRIEL',
#    'DABUL ARIADNA C.',
#    'MALDONADO SONIA',
#    'DUBOWSKI DEBORA',
#    'LOPEZ GUSTAVO',
#    'OLIVERAS PATRICIA',
#    'POMILIO MARIANA',
#    'TRACCHIA EDUARDO',
#    'SILVA ALICIA ITATI',
#    'MESSINA ADRIANA NOEMI',
#    'MARTIRE VERONICA',
#    'CALZONE SERGIO',
#    'COTELLA CLAUDIA',
#    'PEZZELATO GABRIELA',
#    'SIMUTIS ALEJANDRA',
#    'RUBALDO DANIEL',
#    'MOLINA VALERIA',
#    'CARMONA GUSTAVO',
#    'ALADRO, JORGE',
#    'ONGARO JORGELINA',
#    'LICASTRO JOSE',
#    'FAVARO LUCIANA',
#    'DI TIERI JUAN',
#    'BUONO ANA',
#    'WASSOUF GERMAN',
#    'AGÜERO MONICA',
#    'SAVI MARIA EUGENIA',
#    'NALBANDIAN M. CRISTINA',
#    'GONZALEZ CRISTINA',
#    'NASELLI BRUNO',
#    'ARAYA, JAVIER',
#    'NACCARI LILIANA',
#    'ORQUIN MARIA F',
#    'COMI MARIO JORGE',
#    'BADRA JORGE',
#    'ROSSO ELENA',
#    'AQUINO NORBERTO',
#    'SCHENONE MARIA OFELIA',
#    'ALEGRE PAOLA',
#    'AYERBE SILVIO',
#    'GUTIERREZ GASTON',
#    'VILAR LEANDRO',
#    'KALEKA RUTH',
#    'MESSINA SEBASTIAN',
#    'CAPARRA MARCELA',
#    'DE CUNTO VERONICA',
#    'JURI VELIZ GISELA',
#    'LONGHI SILVIA',
#    'FERNANDEZ VAQUERA, B',
#    'PENZA SILVINA',
#    'MOOR LAURA CINTIA',
#    'PACHECO MABEL',
#    'CICCONE GISELA',
#    'GUTIERREZ ALICIA',
#    'PROCUPEZ CLAUDIO',
#    'RIVERO TERRAZAS NOEMI',
#    'TORRISI LUIS',
#    'REZK FRANCISCO',
#    'NATALE, VINCENZO',
#    'BERNARDEZ CARLOS',
#    'MERNES ELSIE',
#    'NEGRETTI NANCY',
#    'CHAIZAZ VALENZUELA TAMARA',
#    'COGLIOLO ANALIA',
#    'MOYA PATRICIA',
#    'VALENZUELA LORENA',
#    'BERNARDO ALICIA',
#    'ALEGRE LUIS',
#    'RODRIGUEZ ROBERTO',
#    'CANDIA SILVIA',
#    'MANDEL MARIO',
#    'SILEO ANALIA',
#    'CAMELINO SUSANA',
#    'BORRI ROMINA',
#    'LEDESMA CARINA',
#    'ZANARDI CRISTINA',
#    'CIGNONI ALEJANDRA',
#    'ABUIN VERONICA',
#    'ARAMAYO FERNANDO',
#    'MORANO ADOLFO',
#    'DICOSTA LILIA',
#    'BAREIRO JUANA',
#    'MERLO CESAR',
#    'PEREZ MONICA',
#    'DITURI ADRIANA',
#    'BONAVITA MARCELA',
#    'SZUMOWSKI CAROLINA',
#    'MADELAIRE LUIS',
#    'VUOTTO GUSTAVO',
#    'AROZTEGUI PATRICIA',
#    'RYSZNIVKIER JESICA',
#    'ASMUS, MERCEDES',
#    'MERA ANDREA',
#    'NICOLINO ORNELA',
#    'FERRARI JAVIER',
#    'SGARBOSSA VALERIA',
#    'FERRARO LAURA',
#    'BOSANO VALERIA',
#    'SANTORO SILVIA',
#    'PEREYRA CYNTHIA',
#    'FIASCHE RUBEN',
#    'TRAVERSA NATALIA',
#    'ESQUEFF ESTELA',
#    'SANTOS, ANALIA',
#    'FORTUNA MARIA LAURA',
#    'FUERTES SANDRA',
#    'VEGA DANIEL',
#    'AJARGO LAURA',
#    'CHICHIZOLA MARIA J.',
#    'DRAGUNSKY MARCELO',
#    'LENAGHAN OSVALDO',
#    'BEITONE VANESA',
#    'CHIRDO FLAVIA',
#    'IRALA ELSA',
#    'DE LUCA ANDREA',
#    'BERNUES PLINIO',
#    'ALEGRE SOLEDAD',
#    'TORRE ANDREA',
#    'AREN MARIA EVA',
#    'DIAZ ERIKA',
#    'LOPEZ KADAR MARCELO',
#    'ALEGRE NATALIA',
#    'TASSI LILIANA',
#    'FERNANDEZ LAVIA JOAQUIN',
#    'LOMBARDO VANESA',
#    'ALVAREZ BEATRIZ',
#    'SANSOLINI DIEGO',
#    'VAINER PABLO',
#    'PUGLIESE ADRIANA',
#    'CRISPINO PAULO',
#    'PATANE GRACIELA',
#    'RUIZ, DANIEL ALBERTO',
#    'TECAZINER LUIS',
#    'OUTON JULIO',
#    'ENTROCASSI PAOLA',
#    'ROMANO DANIEL',
#    'CAPUTO CARLOS',
#    'ZALAZAR PAOLA',
#    'SALDANERI GISELLA',
#    'GROSSI GUILLERMO',
#    'CERRUTI PATRICIA',
#    'GONZALEZ LAURA',
#    'CALVANI ALDANA',
#    'DE LUSARRETA',
#    'CLOCCHIATTI M. CECILIA',
#    'BRONSTAIN JORGE',
#    'ARRIETA SILVIA',
#    'LESCANO MONICA',
#    'PEREZ GUSTAVO',
#    'MOSCOLONI MONICA',
#    'DELL´AGNOLO FLORENCIA',
#    'DUJO ANDREA FABIANA',
#    'GARCIA PAOLA',
#    'BENAVIDEZ MIRNA SAMANTA',
#    'AGUIRRE FLAVIA',
#    'BAJO HERNAN',
#    'VARCHIONI ANDREA',
#    'GOMEZ YAMILA',
#    'MONZON GRACIELA',
#    'BARLETTA PAULA',
#    'BIANCO FIORELLA',
#    'BELTRAMONE INES',
#    'BLANCO RAUL',
#    'ROMERO JORGE',
#    'YAZRA ALDO',
#    'BURGOS MARCELA',
#    'BIANCHI CLAUDIO',
#    'BIANCHI ADRIAN',
#    'SALVADOR M. EUGENIA',
#    'TROBO LAURA',
#    'RADICE KARINA',
#    'ZAPATA MARIA CECILIA',
#    'SAGOL VALERIA',
#    'TROTTA DIEGO',
#    'MANCHINI PABLO',
#    'GARCIA LINARES GERARDO',
#    'BALZANO CARLOS',
#    'ROMERO GERMAN',
#    'PANTANO HORACIO',
#    'REIST MARTA PATRICIA',
#    'AGOSTINI MARIANA',
#    'PONTI CLAUDIA',
#    'GUANO NICOLAS',
#    'GALVEZ GRISELDA',
#    'DIAZ GLADYS',
#    'CASTIGLIONE ROMINA',
#    'RUIZ RICARDO',
#    'SAAD FERNANDO',
#    'PANELO CLAUDIA',
#    'YANKELEVICH PABLO',
#    'LOBO SILVIA MARIANA',
#    'PRADO EVA',
#    'SEDANO FERNANDA',
#    'PERTA AURELIA',
#    'MANGANARO CLAUDIO',
#    'DEL RIO VERONICA',
#    'VALENZUELA, EMMANUEL RODRIGO',
#    'EXPOSITO JORGE',
#    'FISCHER MARIA BELEN',
#    'TROVATO ROMINA',
#    'PALOMINO VERONICA',
#    'SUAREZ MARIA',
#    'DI RISIO DANIELA',
#    'LAMANA ANALIA',
#    'MALAMUT DIEGO JAVIER',
#    'ETCHEVERRY FERNANDO',
#    'LOMBARDI ROMINA',
#    'VILLA STELLA MARIS',
#    'NEME CAROLINA',
#    'FERNANDEZ BEATRIZ',
#    'BOTTOLI OSCAR',
#    'CASTAÑEDA VIVIANA',
#    'TORRISI GRISELDA',
#    'MORANDO GUSTAVO',
#    'GARCIA ARECHA LUIS',
#    'ZARAGOCI SEBASTIAN',
#    'OVIEDO KARINA',
#    'PEREZ ROSANA',
#    'BOGIN VERONICA',
#    'TUSTANOSKI MARCELO',
#    'BATTAGLIA ROSARIO',
#    'YAÑEZ NORA',
#    'CESTER DANIEL',
#    'GOMEZ NELIDA',
#    'VILLACORTA MARIA',
#    'ZOILO JUAN',
#    'SCARANO EMMANUEL',
#    'FERREIRO NESTOR',
#    'MESITI CLAUDIO',
#    'MILAN ORDOQUI JAVIER',
#    'VALDEZ MILTOS ROMINA',
#    'GARCIA PABLO DANIEL',
#    'PIÑEIRO CARINA',
#    'PRUBNER CYNTHIA',
#    'TRANI CLAUDIA',
#    'CRISOFOLI PABLO',
#    'URBANEJA, ESTER',
#    'FAIRCHILD JORGE',
#    'GIACUSA MARIA ALEJANDRA',
#    'SINARDI MARCELO',
#    'GARCIA STELLA'],
#   'SUPERVISOR': ['PATANE ALICIA',
#    'ZOCCALI JOSE LUIS',
#    'ALFARO NADIA',
#    'CAPUTO ROMINA',
#    'ALVAREZ MARTIN',
#    'BREPPE MARISA',
#    'MARTINEZ MARIANA',
#    'BOTANA ANTONIO',
#    'PEREZ PATRICIA',
#    'SOLODUJIN VANINA',
#    'FERNANDEZ JUAN',
#    'GONIONDZKY SILVINA',
#    'BEITONE VANESA',
#    'RIVERO CLAUDIA',
#    'POLICANO ANTONIO',
#    'FIORENZA GUSTAVO',
#    'GONZALEZ CLAUDIA',
#    'ATANIYA DIEGO',
#    'CISNERO DIEGO',
#    'BARBAGELATA RODOLFO',
#    'PINTO JORGE',
#    'MARTIN CAROLINA',
#    'PETRELLA ANTONIO',
#    'ALVAREZ PABLO',
#    'CARLOS SOUTO',
#    'ABELARDO ROMINA',
#    'POSE LUCIANA',
#    'SANTORA ALEJANDRO',
#    'MILMAN MARIANO',
#    'EDREIRA NORMA',
#    'TRICOTTI GABRIELA',
#    'AIELLO EDUARDO',
#    'LENGARD CRISTINA',
#    'GUMUCIO HUMBERTO',
#    'LEGUIZAMON EMANUEL',
#    'GONZALEZ MAURO',
#    nan,
#    'DOMINGUEZ JAVIER',
#    'ARAMBURU GERMAN',
#    'SPERONI MARCELO',
#    'BALZANO CARLOS',
#    "D'APICE ADRIANA",
#    'RUBIO MARCELO',
#    'CEREZO MARCELA',
#    'SALLES, ENRIQUE',
#    'ZELVYS SERGIO',
#    'LASPINA ROXANA',
#    'MANCHINI HERNAN',
#    'ANTONELLI MARTA',
#    'CAPARRA MARCELA',
#    'ARFUSO VIVIANA',
#    'GARCIA STELLA MARIS',
#    "D'AMICO VANINA",
#    'CEPURBEDA JORGE',
#    'BIANCHI MARIA FERNANDA',
#    'GIAMMARCHE DANIEL',
#    'MONTERO FERNANDO',
#    'COHEN, LEONOR',
#    'SANCHEZ ARIAS HILDA',
#    'GARIB JOSE LUIS',
#    'BECERRA PEREZ HUGO',
#    'MERA ANDREA',
#    'COLUCCIO JORGE',
#    'MELILLO MARCELO',
#    'JULIAN YAMIL',
#    'ALVAREZ DANIEL'],
#   'CUIT': ['30710240244',
#    '33707083129',
#    '30529994393',
#    '30708826568',
#    '30708449853',
#    '30647312523',
#    '30707713212',
#    '30687722007',
#    '30612677499',
#    '30539749435',
#    '30702276957',
#    '20127020303',
#    '30709788880',
#    '30500846301',
#    '30646489675',
#    '20937426446',
#    '30708938935',
#    '30712349626',
#    '30708628227',
#    '30643475673',
#    '30712255036',
#    '30691152177',
#    '30501887214',
#    '27003824484',
#    '30504996588',
#    '30709490644',
#    '30711212856',
#    '30711902836',
#    '20041222795',
#    '30708088575',
#    '30685140221',
#    '30711810931',
#    '30710183437',
#    '30708424559',
#    '30709030597',
#    '30709187941',
#    '30709452408',
#    '30711958076',
#    '30708422300',
#    '30707786279',
#    '30709008044',
#    '30708810777',
#    '30592724541',
#    '30708557346',
#    '30681490465',
#    '30714059730',
#    '30677297322',
#    '30709565075',
#    '27138572574',
#    '27382545880',
#    '30709835420',
#    '30570135585',
#    '30551667800',
#    '30502574945',
#    '30709053988',
#    '33500057039',
#    '30710104154',
#    '30711018405',
#    '30648812856',
#    '30711274355',
#    '30711573999',
#    '30708585447',
#    '20936968407',
#    '30711494123',
#    '30710616155',
#    '20078874326',
#    '30.709.710.237',
#    '30709568376',
#    '30646710207',
#    '30500037217',
#    '30712273743',
#    '30709325120',
#    '30527677331',
#    '30711054002',
#    '30712156674',
#    '30541138249',
#    '30604801105',
#    '30692324605',
#    '20130229787',
#    '30710263015',
#    '20131315067',
#    '30659867504',
#    '30684968528',
#    '30690995170',
#    '30574816870',
#    '30609645977',
#    '30707813543',
#    '30711259534',
#    '30696041640',
#    '30710935196',
#    '33710301919',
#    '30656171827',
#    '30657107758',
#    '30549547288',
#    '30500051309',
#    '30713110406',
#    '20329194990',
#    '33578969409',
#    '20076564257',
#    '30710488327',
#    '30707681019',
#    '20043176391',
#    '30709051659',
#    '30502793175',
#    '30610252334',
#    '30710852916',
#    '30642025615',
#    '30537131000',
#    '30708143762',
#    '30685793136',
#    '30708434686',
#    '30693290925',
#    '30710640285',
#    '30609788352',
#    '30500050795',
#    '33707830889',
#    '30709264482',
#    '30712549838',
#    '20263598157',
#    '30679732532',
#    '30653484778',
#    '30710443471',
#    '30676613303',
#    '30707279547',
#    '30632464904',
#    '27222406892',
#    '30500064478',
#    '30711227675',
#    '30699408154',
#    '30518919349',
#    '30707385525',
#    '30601002651',
#    '30687471349',
#    '30710689640',
#    '33645022659',
#    '30533285119',
#    '33547992429',
#    '30500045406',
#    '30507066824',
#    '30678184779',
#    '30695108520',
#    '30690973517',
#    '30707813780',
#    '33573855839',
#    '30646279174',
#    '30708515791',
#    '30710821204',
#    '30709228494',
#    '30685781502',
#    '30711352844',
#    '30708643331',
#    '30500143297',
#    '30707946144',
#    '30712203273',
#    '30710180004',
#    '30504913712',
#    '30694747546',
#    '33708555709',
#    '30652248582',
#    '30612032846',
#    '30710969244',
#    '30709439754',
#    '30659932640',
#    '27145584162',
#    '20266320915',
#    '30690785052',
#    '30500772324',
#    '27255257701',
#    '30550119745',
#    '30711355371',
#    '30709425389',
#    '30521092501',
#    '20176356139',
#    '30500010602',
#    '30671375900',
#    '30500010912',
#    '30500012516',
#    '30671859339',
#    '30500009442',
#    '30500098801',
#    '33686664649',
#    '30704960995',
#    '30500012443',
#    '30518954241',
#    '30522714417',
#    '30580189411',
#    '30500010084',
#    '30500006613',
#    '30569151763',
#    '33500005179',
#    '30500005179',
#    '30546741636',
#    '23928913244',
#    '27000522738',
#    '27025029157',
#    '23946043664',
#    '20180946641',
#    '20219541660',
#    '30708946563',
#    '20164920144',
#    '30711109850',
#    '30695558208',
#    '20352298108',
#    '30691323958',
#    '20134804212',
#    '30500064230',
#    '30714092517',
#    '30999228565',
#    '30711770441',
#    '30677428402',
#    '30678172762',
#    '30710016255',
#    '20145633851',
#    '30568222187',
#    '20163771064',
#    '30708112824',
#    '20045521215',
#    '30500035788',
#    '30685893076',
#    '30711043140',
#    '30500678042',
#    '30711304173',
#    '30662982837',
#    '30708568240',
#    '30693503953',
#    '30693504186',
#    '30696159609',
#    '30710844131',
#    '30711878633',
#    '30663391026',
#    '30678158506',
#    '20131325062',
#    '30709560650',
#    '30694376432',
#    '30707498338',
#    '30649364040',
#    '30709925322',
#    '30692311392',
#    '30711853959',
#    '30709334685',
#    '23933685799',
#    '30710523521',
#    '30690207423',
#    '30574893395',
#    '30707044299',
#    '30582170653',
#    '30537486410',
#    '30566275232',
#    '30710859317',
#    '30714367540',
#    '27176122000',
#    '30500001115',
#    '30525586878',
#    '33710499409',
#    '30690196634',
#    '20183791924',
#    '30708239972',
#    '30500034552',
#    '30710811160',
#    '27039768297',
#    '30519882767',
#    '30708440546',
#    '30708206624',
#    '30687288145',
#    '30711635366',
#    '20105505494',
#    '20112256025',
#    '30599017433',
#    '30710219865',
#    '20120864425',
#    '30582202253',
#    '30647218489',
#    '30707735607',
#    '30709779164',
#    '30680718268',
#    '30680748876',
#    '30594336247',
#    '30707879234',
#    '30707264951',
#    '30708656832',
#    '30708834560',
#    '20045420370',
#    '30705644310',
#    '30537341811',
#    '30711981531',
#    '30710983107',
#    '30707732055',
#    '30707419497',
#    '20245642033',
#    '30663205621',
#    '30500039678',
#    '30709210293',
#    '30707979050',
#    '20169730785',
#    '30551291290',
#    '20288034843',
#    '23238660939',
#    '30657864281',
#    '20172327576',
#    '30708621761',
#    '30621500917',
#    '20102017871',
#    '20225487018',
#    '27120860459',
#    '30698744177',
#    '30708983906',
#    '30615911654',
#    '30640324097',
#    '20139773889',
#    '20940987947',
#    '30693215311',
#    '30677558268',
#    '30711416508',
#    '20166808201',
#    '30711125155',
#    '30711966052',
#    '30708130865',
#    '20234632338',
#    '30584620389',
#    '23200093119',
#    '30550095714',
#    '30526008835',
#    '30538058743',
#    '30678264659',
#    '30577466102',
#    '23938772304',
#    '20231549804',
#    '20043043162',
#    '20226532537',
#    '20182988503',
#    '27208324182',
#    '20127025968',
#    '30709492922',
#    '30712028382',
#    '20042953874',
#    '30636345454',
#    '27930868472',
#    '30658963895',
#    '30501111747',
#    '30646451422',
#    '30709272914',
#    '30710164637',
#    '30590360763',
#    '30708167300',
#    '30707813519',
#    '30546128403',
#    '30658804657',
#    '30652543630',
#    '30708927763',
#    '30712411364',
#    '30709460532',
#    '30575054354',
#    '23124548799',
#    '30652834317',
#    '20044148723',
#    '33508358259',
#    '30623347296',
#    '20231015117',
#    '30708927690',
#    '33624100439',
#    '27940288024',
#    '27939377048',
#    '27247530229',
#    '20042235068',
#    '30523479241',
#    '30708290447',
#    '27321880776',
#    '30710791550',
#    '20928915025',
#    '27928720425',
#    '30708602619',
#    '23043163019',
#    '30685158341',
#    '30709858773',
#    '30500032266',
#    '30708420189',
#    '30708044985',
#    '30695305644',
#    '30708617632',
#    '30500036911',
#    '30689011051',
#    '20291355936',
#    '27214740422',
#    '30636741120',
#    '30709787442',
#    '30517675292',
#    '30557107416',
#    '30708135433',
#    '30709390682',
#    '30500005625',
#    '30709247820',
#    '30710659717',
#    '30707176284',
#    '20102333951',
#    '30708709227',
#    '30504912899',
#    '27045518472',
#    '30654181744',
#    '30658422762',
#    '30628436238',
#    '30708327472',
#    '30711479399',
#    '30711448442',
#    '33707725929',
#    '30682408622',
#    '30552483304',
#    '30711070725',
#    '30525390086',
#    '30664021435',
#    '30599942226',
#    '30709550949',
#    '27248821499',
#    '33711009359',
#    '30708743476',
#    '30520760535',
#    '30561625960',
#    '30691618389',
#    '33711696259',
#    '30568642186',
#    '30696899459',
#    '30707021426',
#    '30711656231',
#    '30711322236',
#    '30709876984',
#    '30709193984',
#    '30697250367',
#    '30710739729',
#    '30649229755',
#    '30710345364',
#    '30506733932',
#    '30626221811',
#    '30708376740',
#    '30652012465',
#    '30708403195',
#    '30709063800',
#    '30581570313',
#    '30707735127',
#    '30708908378',
#    '30710831978',
#    '30655037248',
#    '30709418659',
#    '30708239824',
#    '30708886595',
#    '33710114299',
#    '30712860509',
#    '30546694646',
#    '30633369220',
#    '30711641641',
#    '33710018079',
#    '30710593570',
#    '30705451040',
#    '30708389168',
#    '30708676906',
#    '30566207377',
#    '30710634447',
#    '30710236050',
#    '30710422946',
#    '33711952549',
#    '30633390688',
#    '30590745797',
#    '30561788096',
#    '30661957065',
#    '30707804617',
#    '30708190426',
#    '30518965715',
#    '30662934174',
#    '30709615846',
#    '30709982350',
#    '30708447494',
#    '30624185044',
#    '30673380162',
#    '27056657695',
#    '30708204907',
#    '30650156109',
#    '20240833914',
#    '30711097674',
#    '30632560717',
#    '30709764809',
#    '33709416869',
#    '30709479624',
#    '20082088963',
#    '30713060506',
#    '30711007047',
#    '30710277334',
#    '30567998130',
#    '30712231250',
#    '30711406995',
#    '30707937382',
#    '30707201882',
#    '30624349004',
#    '30697986126',
#    '30682503994',
#    '27162229430',
#    '30708494107',
#    '20045845177',
#    '30503517767',
#    '30709207209',
#    '30588223775',
#    '30622216309',
#    '30710957157',
#    '30710779062',
#    '30509300700',
#    '30589398951',
#    '27104634120',
#    '30711854629',
#    '30701019268',
#    '30615474653',
#    '20942768185',
#    '30712332006',
#    '30708706791',
#    '30702033639',
#    '33709828369',
#    '30708201657',
#    '30711274223',
#    '23177555789',
#    '30559161949',
#    '30711531293',
#    '30710663072',
#    '30708671491',
#    '30709240567',
#    '33695610659',
#    '30640766030',
#    '33709116539',
#    '30677757814',
#    '30710777086',
#    '20367283085',
#    '20345343793',
#    '30708368772',
#    '30709274674',
#    '30711658684',
#    '30553566602',
#    '20160501104',
#    '20211398915',
#    '30684734799',
#    '20231025686',
#    '30710855206',
#    '30708065508',
#    '30601951394',
#    '30596116201',
#    '30712455906',
#    '20223623191',
#    '30710721102',
#    '20290381852',
#    '20280306011',
#    '30500876391',
#    '20085864905',
#    '30712488065',
#    '30707874259',
#    '30607462905',
#    '33663184739',
#    '30711460051',
#    '27923427886',
#    '30598083890',
#    '20233291065',
#    '33684058679',
#    '30655189730',
#    '20126017856',
#    '30707463178',
#    '33629282659',
#    '20186513437',
#    '27172947714',
#    '30685146335',
#    '30632345476',
#    '20044152607',
#    '30701307115',
#    '20041707292',
#    '30707397760',
#    '30707921214',
#    '30580111315',
#    '20042338002',
#    '30685849751',
#    '30708741163',
#    '20111687413',
#    '20162463315',
#    '30551518694',
#    '30693283724',
#    '20221476213',
#    '30710685033',
#    '30708253010',
#    '30707830960',
#    '30596118352',
#    '27948025294',
#    '30546696968',
#    '30685889397',
#    '30710597651',
#    '33711113539',
#    '30711268215',
#    '30696731825',
#    '33708522819',
#    '33642616949',
#    '33709496919',
#    '33657865279',
#    '30708879017',
#    '30708935650',
#    '33709418489',
#    '30686869098',
#    '30709014184',
#    '30712063900',
#    '33708255349',
#    '20077309403',
#    '30708112727',
#    '30711309086',
#    '20134654091',
#    '27259874160',
#    '30636021578',
#    '30707439587',
#    '30606801765',
#    '30708428147',
#    '30707085882',
#    '30609373020',
#    '30708450525',
#    '30682100989',
#    '30663163090',
#    '30685850601',
#    '30694382408',
#    '33519957979',
#    '30709683833',
#    '30589891046',
#    '30709255653',
#    '30608722749',
#    '30661144226',
#    '33702669249',
#    '27256467637',
#    '30710343779',
#    '30514562411',
#    '30500033254',
#    '30501117230',
#    '30519165496',
#    '30707270930',
#    '30712174486',
#    '30711416702',
#    '30708514051',
#    '30701829723',
#    '33619678929',
#    '30500039430',
#    '30714034541',
#    '20316751041',
#    '30710239858',
#    '30707709959',
#    '30612843151',
#    '30643586777',
#    '30707593128',
#    '30654464924',
#    '30709586269',
#    '33714207089',
#    '30707522581',
#    '30704771998',
#    '30711817367',
#    '30595793404',
#    '30707301631',
#    '33709271909',
#    '30611777368',
#    '30695445985',
#    '30512823099',
#    '20124595305',
#    '30712005285',
#    '30610747473',
#    '30680823185',
#    '30708743514',
#    '30708968087',
#    '30708301953',
#    '30519746863',
#    '20043688767',
#    '27179533052',
#    '30504126974',
#    '20220971229',
#    '30500059709',
#    '30593598566',
#    '30711017603',
#    '30631356288',
#    '30541814813',
#    '30711500851',
#    '30653764819',
#    '30711411034',
#    '30500394184',
#    '33708414609',
#    '30537679855',
#    '30610440580',
#    '30711958033',
#    '33712552919',
#    '33710760689',
#    '30712328920',
#    '30699140984',
#    '30708376341',
#    '30707007431',
#    '30531967093',
#    '30645887111',
#    '30702250400',
#    '30707001255',
#    '30579607552',
#    '30556089147',
#    '33711878209',
#    '30707407006',
#    '30711042772',
#    '30661942777',
#    '30629640386',
#    '30711530831',
#    '30504835126',
#    '30708925949',
#    '30709752118',
#    '30642930067',
#    '30693287304',
#    '33710074289',
#    '27169752708',
#    '30709491306',
#    '30682519416',
#    '20134112493',
#    '30656112456',
#    '30656258736',
#    '30710348886',
#    '30711888132',
#    '33707366589',
#    '30678784288',
#    '30710007523',
#    '20076985724',
#    '30707373934',
#    '33500237789',
#    '30710585616',
#    '30707714251',
#    '20118242786',
#    '20045395899',
#    '20041901412',
#    '27259404988',
#    '30655118043',
#    '30712871802',
#    '30500055053',
#    '30682450963',
#    '30712148299',
#    '30711295735',
#    '30711539936',
#    '30712023658',
#    '30712544607',
#    '30711338507',
#    '30711994587',
#    '20233313778',
#    '20085031644',
#    '20202255257',
#    '20160713004',
#    '20045528724',
#    '33707027369',
#    '30519663844',
#    '30710435479',
#    '33708062389',
#    '30636048638',
#    '30522211563',
#    '30710196032',
#    '30687677478',
#    '27937938883',
#    '24060391986',
#    '20130383204',
#    '30663455830',
#    '30634566623',
#    '30708010436',
#    '30609823190',
#    '30600196622',
#    '30619447928',
#    '30502752924',
#    '30708065559',
#    '30709552283',
#    '30707992677',
#    '30526874249',
#    '27065131582',
#    '30710065280',
#    '33623865849',
#    '30504540177',
#    '30708113480',
#    '30686265389',
#    '30613917272',
#    '30711948909',
#    '30631536790',
#    '30709069183',
#    '33653239829',
#    '30606966632',
#    '20146192670',
#    '30707884300',
#    '33711681499',
#    '30707962743',
#    '30698376100',
#    '30640368698',
#    '20139950357',
#    '30685228501',
#    '30525399474',
#    '30687145522',
#    '27161613938',
#    '30712241884',
#    '20204929026',
#    '27020456855',
#    '33636541899',
#    '30710576560',
#    '30696857837',
#    '20050718957',
#    '30708082526',
#    '27235522913',
#    '27246468569',
#    '20920278818',
#    '20221067410',
#    '33709728119',
#    '30657865725',
#    '20174062219',
#    '20106648140',
#    '30698421289',
#    '30708302283',
#    '30679911054',
#    '30655078874',
#    '30709641871',
#    '30678547219',
#    '30709220124',
#    '30677290478',
#    '30661642501',
#    '30589349063',
#    '30702974255',
#    '30708689579',
#    '30690212265',
#    '30708413166',
#    '30700503891',
#    '20108327570',
#    '20204051497',
#    '30661717889',
#    '20132220965',
#    '27282335226',
#    '30708965266',
#    '20042798046',
#    '20147453265',
#    '30708457929',
#    '30708537272',
#    '30700989050',
#    '30707127437',
#    '30711756341',
#    '30708767928',
#    '30503270230',
#    '30710254466',
#    '30640079378',
#    '20181644347',
#    '20317227095',
#    '20219801778',
#    '20127144657',
#    '20218325638',
#    '23133946829',
#    '27062075371',
#    '30708106352',
#    '20188620036',
#    '30711548250',
#    '30710156537',
#    '30710354614',
#    '30693507533',
#    '30711264856',
#    '20169768820',
#    '33711757029',
#    '20258468393',
#    '30630867971',
#    '30645111881',
#    '30506746627',
#    '20.112.486.934,00',
#    '27267661931',
#    '30500781293',
#    '23045658414',
#    '20281678370',
#    '30711525455',
#    '30684829102',
#    '30709481718',
#    '30700570459',
#    '30714111805',
#    '30617442937',
#    '30710752113',
#    '30710915969',
#    '30709891428',
#    '30709375861',
#    '30708690925',
#    '23076160589',
#    '30709001651',
#    '23264201039',
#    '20219826215',
#    '20083217910',
#    '30659939122',
#    '3071025075',
#    '27170303763',
#    '30708244208',
#    '30710109202',
#    '20309268769',
#    '27928198362',
#    '30710233744',
#    '30570945285',
#    '30707623272',
#    '33697235049',
#    '20946994864',
#    '30509031750',
#    '33707965849',
#    '30711698570',
#    '30710804245',
#    '30604601491',
#    '33516776469',
#    '30557480907',
#    '30709218405',
#    '30710404794',
#    '30708689994',
#    '30577546777',
#    '30712096191',
#    '33562773539',
#    '27109733070',
#    '33537186009',
#    '30643103652',
#    '30663221317',
#    '27937655652',
#    '30711046956',
#    '30711017697',
#    '27940107968',
#    '27943462610',
#    '30707689915',
#    '20137745195',
#    '30708744480',
#    '30643315684',
#    '30503961268',
#    '30701009610',
#    '30708198400',
#    '30568457451',
#    '20085050061',
#    '30653383912',
#    '30516508341',
#    '30714338354',
#    '30710011733',
#    '30708892714',
#    '30708393998',
#    '30708639040',
#    '30707693823',
#    '30505316173',
#    '30711583846',
#    '34502140193',
#    '30611861547',
#    '30708516445',
#    '30610488079',
#    '30710574622',
#    '30711380708',
#    '30709505846',
#    '30643987011',
#    '30602756773',
#    '30690796216',
#    '30711588910',
#    '3057680787',
#    '30686293846',
#    '30209773289',
#    '33708863179',
#    '33701991279',
#    '30500063242',
#    '30711612463',
#    '30707250484',
#    '30708435305',
#    '33610485869',
#    '30708090286',
#    '30712257500',
#    '30686735342',
#    '30704961983',
#    '30696225423',
#    '30620833173',
#    '30710688415',
#    '30708118652',
#    '30707818057',
#    '30689026652',
#    '30710882742',
#    '20173647183',
#    '30708652691',
#    '30709464937',
#    '30708023910',
#    '30711981833',
#    '20123617100',
#    '30711603235',
#    '30711695536',
#    '30708294450',
#    '30655585644',
#    '20087045588',
#    '30694527015',
#    '30708473339',
#    '27141088829',
#    '30700896621',
#    '30501579471',
#    '30710500300',
#    '30712230173',
#    '30709566810',
#    '33712151949',
#    '30501336846',
#    '30500563059',
#    '30708416483',
#    '27108304109',
#    '20040186167',
#    '30501120479',
#    '30709954420',
#    '30598129246',
#    '30709426903',
#    '30.711.670.196,00',
#    '33707334539',
#    '30707846964',
#    '30708101180',
#    '30713316004',
#    '33701981869',
#    '33653335259',
#    '33639585889',
#    '30644102498',
#    '20040869904',
#    '30525436817',
#    '30502015075',
#    '30708905107',
#    ...],
#   'RAZON_SOCIAL': ['1001 FARDO SRL',
#    '25 HORAS SA',
#    '3M ARGENTINA SACIFIA',
#    '4 M SOCIEDAD DE RESPONSABILIDAD LTDA',
#    '5TH ESSENCE S.A',
#    'A M SEGURIDAD SRL',
#    'A NOVO ARGENTINA SA',
#    'A RUSSONIELLO SA',
#    'A Y M D´ESPOSITO SRL',
#    'A.Z. CHAITAS',
#    'A´ZAEL SA',
#    'ABADIE RUBEN HECTOR',
#    'ABASTO NUEVO SA',
#    'ABBOTT LABORATORIES ARG.SA',
#    'ABD S.A.',
#    'ABENIA, PEREYRA',
#    'ABUCA S.A.',
#    'ABYMES SA',
#    'AC ANDRE CARGAS SRL',
#    'AC METAL S. A.',
#    'ACE AMERICAN INSURANCE',
#    'ACECO ARGENTINA SA',
#    'ACEROS ANGELETTI SA',
#    'ACEVEDO, TOLINDA',
#    'ACOPLADOS SALTO S.A.',
#    'ACP SEGURIDAD S.A.',
#    'ACUAVIT S.A.',
#    'ADAN BS AS SRL',
#    'ADANO JORGE ENRI',
#    'ADELIDE SA',
#    'ADIDAS ARGENTINA S.A.',
#    'ADPE SA',
#    'ADRIAN MERCADO SA',
#    'ADROGUE BUS SRL',
#    'ADVENT ARGENTINA SRAL',
#    'AFIANZADORA LATINOAMERICANA COPAÑIA DE SEGUROS S.A.',
#    'AFINA SRL',
#    'AGIR S.R.L.',
#    'AGM MOTOS SRL',
#    'AGRI FOOD SA',
#    'AGRIPER SA',
#    'AGRO SHEEP SRL',
#    'AGROFINA SA',
#    'AGROSERVICIOS CAPDEVIELLE S.A.',
#    'AGROSERVICIOS PAMPEANOS S.A.',
#    'AGROSUR NEGOCIOS INTEGRADOS S.A.',
#    'AGU S.R.L.',
#    'AGUA Y SANEAMIENTOS ARG. SA (AYSA)',
#    'AGUA Y SANEAMIENTOS ARGENTINA SA',
#    'AGUILAR VILMA GREGORIA',
#    'AHUMADA MARIANELA AZUCENA',
#    'AILLING SA',
#    'AIR S.R.L.',
#    'AITOR IDER BALBO SAACEI',
#    'ALADDIN S.R.L.',
#    'ALAKEFAK S.R.L',
#    'ALBA COMPANIA ARGENTINA DE SEGUROS SA',
#    'ALECOLOR SRL',
#    'ALEDI SUR SRL',
#    'ALETAN SRL',
#    'ALFA ENERGIA SA',
#    'ALFAR CONSTRUCCIONES SA',
#    'ALFERCARD SRL',
#    'ALFONSIN BARREIRO MANUEL',
#    'ALIERS SA',
#    'ALIMENTOS SUREÑOS SA',
#    'ALIO ALBERTO ENRIQUE',
#    'ALIWEN INCOMING SRL',
#    'ALL DENIM SA',
#    'ALL IMPORT SA',
#    'ALLIANZ ARGENTINA COMPANIA DE SEGUROS SA',
#    'ALLIANZ RE ARGENTINA SA',
#    'ALTA DENSIDAD SRL',
#    'ALTO PALERMO SA APSA',
#    'ALVAMOS SA',
#    'ALZA GROUP S.A.',
#    'ALZAGA UNZUE Y CIA SA',
#    'AMACON TOURS SRL',
#    'AMADEUS ARGENTINA SA',
#    'AMADO, MIGUEL MEZA',
#    'AMAFREN S.A.',
#    'AMANTO JORGE ALBERTO',
#    'AMBAR CIA MINERA SA',
#    'AMERICA AUTOPIEZAS SA',
#    'AMERICA BLINDAJES S.A.',
#    'AMERICAN EXPRESS SA',
#    'AMERICAN HOME ASSURANCE COMPANY',
#    'AMERICAN TRACER SA',
#    'AMERINODE S.R.L.',
#    'AMIPLAST S.H. DE ROQUE AMIANO Y M. AMIANO',
#    'AMUR CAR S.A.',
#    'AMUSH SA',
#    'ANGIOCOR SA',
#    'ANGLOS S.A.',
#    'ANSELMO L MORVILLO SA (G.C.)',
#    'ANTARTIDA CIA ARG DE SEGUROS S.A',
#    'ANTHOLOGY SA',
#    'ANTOLIN, MARTIN',
#    'ANUNTIS SEGUNDAMANO ARGENTINA S.A.',
#    'AÑION JOSE ALBERTO',
#    'AON RE ARGENTINA BENFIELD ARGENTINA S.A.',
#    'APPAREL ARGENTINA SA',
#    'AQUIN, ARMANDO',
#    'ARCADI S. A.',
#    'ARCOR SAIC',
#    'ARCOS DORADOS SA',
#    'AREDA SRL',
#    'ARETINA SOCIEDAD ANONIMA',
#    'ARFINSA ARGENTINA FINANCIERA SA',
#    'ARGENIT SA',
#    'ARGENPROM S.R.L.',
#    'ARGENTINA COLOR SRL',
#    'ARGENTINAIR SA',
#    'ARGENTO DARDO GABRIEL OLMOS PABLO',
#    'ARGENTOL SA',
#    'ARGOS CIA DE SEGUROS GENERALES SA',
#    'ARKINO SA',
#    'ARL SA',
#    'AROMAS DEL BOTANICO SRL',
#    'ARPINI LEONARDO LUIS',
#    'ARREDO SA',
#    'ARROW SERVICIOS SRL',
#    'ARTE ENCUADERNACION SRL',
#    'ARTES CONTINUAS SRL',
#    'ARTES GRAFICAS ALEXANDER FLEMING SA',
#    'ARUBRAS S.A.',
#    'ASCARRAGA GABRIELA ALEJANDRA',
#    'ASEG.DE CRED. GARANTIAS SA',
#    'ASEGURADORA DE RIESGOS DEL TRABAJO LIDERAR',
#    'ASEGURADORA TOTAL MOTOVEHICULAR SA',
#    'ASEGURADORES DE CAUCIONES SA',
#    'ASHIR TECHNOLOGY CORP SRL',
#    'ASHIRA SA',
#    'ASISGER S.R.L.',
#    'ASMEC SRL',
#    'ASOC ARG DE PROTECCION DE LAS OBT VEGETALES (ARPOV)',
#    'ASOPROFARMA AOSC PROP DE FARMACIAS COOP PROVENSIN',
#    'ASSIST CARD ARGENTINA S.A. DE SERV.',
#    'ASSURANT ARGENTINA COMPAÑIA DE SEGUROS S.A.',
#    'ASTILLEROS NEPTUNO SA',
#    'ASV ARGENTINA SA',
#    'AT HOME SRL',
#    'ATENCION AMBULATORIA S.A.',
#    'ATMED SRL',
#    'ATOMLUX SA',
#    'ATS ADVANCED TECHNOLOGY SA',
#    'ATTO SRL',
#    'AUGEMI SRL',
#    'AUGRAF SRL',
#    'AUTO GENEALI S.A.',
#    'AUTO LENKEN SA',
#    'AUTOMAC SOCIEDAD ANONIMA',
#    'AUTOMOVIL CLUB ARGENTINO',
#    'AUTOPARTES POMPEYA S.R.L.',
#    'AUTOPRANA SA',
#    'AUTOSERVICIO SANTA LUCIA SRL',
#    'AUTOTROL S.A.',
#    'AUTOVISIONES S.A.',
#    'AV.INDEPENDFENCIA S.R.L.',
#    'AVE CEASER SRL',
#    'AVH SAN LUIS SRL',
#    'AVICOLA OVO SRL',
#    'AVSA ATENCION VEHICULAR SA',
#    'AWARDS CINE SRL',
#    'AYE ALI MARGARITA IRIS',
#    'AYERZA FRANCISCO',
#    'AZILUT S.A.',
#    'AZTRAZENECA SA',
#    'BAEZ, CAROL BETIANA',
#    'BAGALA SA',
#    'BAGO GROUP SA',
#    'BAITCON SA',
#    'BALIARDA SA',
#    'BALLESTRACCI ADOLFO ORLANDO',
#    'BANCO DE CORRIENTES S.A.',
#    'BANCO DE FORMOSA S.A.',
#    'BANCO DE LA NACION ARGENTINA',
#    'BANCO DE LA PAMPA SEM',
#    'BANCO DE LA RIOJA SA',
#    'BANCO DE SAN JUAN SA',
#    'BANCO DE SANTA CRUZ S.A.',
#    'BANCO DE SANTIAGO DEL ESTERO S.A.',
#    'BANCO DE SERVICIOS Y TRANSACCIONES SA',
#    'BANCO DO BRASIL SA',
#    'BANCO FINANSUR SA',
#    'BANCO INTERFINANZAS S.A.',
#    'BANCO ITAU ARGENTINA S.A.',
#    'BANCO MACRO SA',
#    'BANCO PATAGONIA SA',
#    'BANCO PIANO S.A.',
#    'BANCO SUPERVIELLE',
#    'BANCO SUPERVIELLE SA',
#    'BANCO SUPERVILLE SA',
#    'BANCO VOII SA',
#    'BANG JUN LIM',
#    'BAQARES NELIDA',
#    'BARBERO DELFINA',
#    'BAREGHAMYAN PIRUZ',
#    'BARGAS EDUARDO DANIEL',
#    'BARILA MARIANO GABRIEL',
#    'BARNEOS REPS TURISTICAS S.R.L.',
#    'BARSKY GERARDO EMILIO',
#    'BARTOKBAR SRL',
#    'BASF POLIURETANOS S.A.',
#    'BATAGLIESI JUAN MARTIN',
#    'BATERIAS ARGENTINAS S.A',
#    'BATTISACHI EDUARDO HECTOR',
#    'BBVA CONSOLIDAR SEGUROS SA',
#    'BCN CYS SRL',
#    'BCO. DE LA PCIA. DE CORDOBA S.A.',
#    'BE SINGULAR S.A.',
#    'BEBY ROP S.A.',
#    'BEFESA ARGENTINA SA',
#    'BELDORA ARGENTINA SOCIEDAD ANONIMA',
#    'BELLANDI ROBERTO',
#    'BELLINI SRL',
#    'BELTRAN RAMON ENRIQUE',
#    'BENNY PEN ARGENTINA SA',
#    'BEREMBAUM ALBERTO B.',
#    'BERKLAY INTERNATIONAL SEGUROS S.A.',
#    'BERKLEY INTERNATIONAL ART',
#    'BERNAGO MARKETING SERVICES S.A.',
#    'BESSONE S.A.',
#    'BEST COFFEE SA',
#    'BETA MOTOR ARGENTINA S.A.',
#    'BETONHAUS SA',
#    'BHN VIDA SA.',
#    'BHN SEGUROS GENERALES S.A.',
#    'BIANCHI VENDING ARGENTINA S.A.',
#    'BIBICI S.R.L.',
#    'BIGUEST SA',
#    'BIJOU CASTELLI SA',
#    'BINARIA SEGUROS DE VIDA SA',
#    'BINDI GABRIEL ANTONIO',
#    'BIO LAP SA',
#    'BIOMERIEUX ARGENTINA SA',
#    'BIOPHARMA SRL',
#    'BIOPROFARMA SA',
#    'BIOTRANS SRL',
#    'BLAISTEN SA',
#    'BLANCO ESPECIAL SA',
#    'BLANCO EUROPA SA',
#    'BLANCO JUAN',
#    'BLANCO MARQUEZ SRL',
#    'BLANCO MONTAJES SA',
#    'BLOISE G. Y BLOISE A SOC DE HECHO',
#    'BOEDO SUR S.A.',
#    'BOLSA DE COMERCIO DE BAHIA BLANCA SA',
#    'BOLSA DE COMERCIO DE LA PLATA',
#    'BOLSA DE COMERCIO DE SANTA FE',
#    'BOOK COMPAY SRL',
#    'BORAL INVERSIONES SRL',
#    'BOSSOTTO GRETA ELIZABETH',
#    'BOSTON CIA SEGUROS SA',
#    'BOUILLARD Y CIA.',
#    'BOUTIQUE GRAFICA SRL',
#    'BOW  SRL',
#    'BOZZI GUSTAVO LEONARDO',
#    'BPAR S.A.',
#    'BRADESCO ARGENTINA DE SEGUROS SA',
#    'BRAKU SA',
#    'BREWDA AIDA',
#    'BREWDA CONSTRUCCIONES SA',
#    'BRIEF AUSTRALIA SRL',
#    'BRIEFING SECURITY S.A.',
#    "BRINK'S ARGENTINA S.A.",
#    'BRINMETAL S.A.',
#    'BRITO JORGE HORACIO',
#    'BRIZUELA RAUL OSCAR',
#    'BRONS SALAS SC',
#    'BRONWAY TECHNOLOGY SA',
#    'BRUALLA ALEJANDRO',
#    'BRUNO HNOS SA',
#    'BSH ELECTRODOMESTICOS SA',
#    'BSQ SERVICIOS SRL',
#    'BUCAREL S.R.L.',
#    'BUFANO S.A.',
#    'BUNKERBAIRES S.A.',
#    'BUONCAFF SRL',
#    'BUREAU INVESTIGACIONES SA',
#    'BURGWARDT Y CIA SAICA',
#    'C.M. TEXTILES SA',
#    'C3 ARQUITECTURA Y CONSTRUCCIONES SRL',
#    'CABADO OSVALDO',
#    'CABALLITO SANITARIOS S.R.L.',
#    'CABAÑA AVICOLA JORJU S.A.',
#    'CABATEX SA',
#    'CACIC SPORTS VISION SRL',
#    'CAFE ROCAMORA SRL',
#    'CAFE SIBARITA SRL',
#    'CAFICI FRANCISCO HERNAN',
#    'CAJA DE SEGUROS S.A.',
#    'CALEDONIA ARG. CIA DE SEG. SA',
#    'CALTOUR RECEPTIVE SERVICE S.R.L.',
#    'CALZADOS GUSTI S.R.L.',
#    'CAMARA HERNANDEZ DIEGO',
#    'CAMBIO AMERICA S.A.C.T',
#    'CAMOZZI FERNANDO ARIEL',
#    'CAMPI EMILIANO',
#    'CAMUZZI GAS PAMPEANA SA',
#    'CANABAL NAGY CRISTIAN MARTIN',
#    'CANTERAS POMPEYA S.A',
#    'CANTONE HAYDEE Y PARISOTO DIANA SH',
#    'CAPANNA RICARDO JOSE',
#    'CAPITAINE MARCELO',
#    'CAPPO GLADIS ALICIA',
#    'CAR SECURITY SA',
#    'CARAT ARGENTINA SA',
#    'CARAVANAS SCA',
#    'CARDA SA',
#    'CARDENAS OSCAR ANTONIO',
#    'CARDENAS REATEGUI GERMAN',
#    'CARDIF SEGUROS SA',
#    'CARGOS SERVICIOS INDUSTRIALES SA',
#    'CARIZ SA',
#    'CARLOS ALBERTO QUIRINO',
#    'CARLOS Y JORGE ELIAS S. DE.H',
#    'CARNES DOCC SRL',
#    'CAROTEX S.R.L. DEVOLUCION',
#    'CARRACEDO, HERNAN',
#    'CARREFOUR AGENTINA SA',
#    'CARTASSO NAVEYRA EDUARDO',
#    'CASA JERSE SAIC',
#    'CASA OTTO HESS SACI',
#    'CASA RUBIO SA',
#    'CASA RULITO DE FERNANDEZ HORACIO Y FERNANDEZ ERNESTO SH',
#    'CASA TRASORRAS SOCIEDAD COLECTIVA',
#    'CASAHUMA AZAÑA',
#    'CASAS NORBERTO GERARO',
#    'CASATI NORBERTO',
#    'CASTELLI EUGENIO',
#    'CASTILLA MADEO MARCOS',
#    'CASTRO MARIA JOSE',
#    'CASTRO, JOSE EZEQUIEL',
#    'CAT TECHNOLOGIES ARG SA',
#    'CATALINA SUR SA',
#    'CATANIA ANTONIO JOSE',
#    'CATTER MEAT S.A.',
#    'CAYO, MEDIANO',
#    'CAZADORES COOPERATIVA DE TRABAJO LTDA.',
#    'CCI CONSTRUCCIONES SA (SCE)',
#    'CCR SA (SCE)',
#    'CELULOSA LA MESOPOTAMIA SA',
#    'CEMAFELU SA',
#    'CENCOSUD SA',
#    'CENTRAL DE LOGISTICA INTEGRADA S.A.',
#    'CENTRO BOX SRL',
#    'CENTRO DE EDUCACION MEDICA E INVESTIGACION NORBERTO QUIRNO',
#    'CENTRO DEL NORTE S.A.',
#    'CENTRO PRIVADO DE SALUD MENTAL S.R.L.',
#    'CENTURY GREEN SA',
#    'CERAMICOS MA ROS S.A.',
#    'CEREALERA LAS VARAS SA',
#    'CEREALES CEPREN SA',
#    'CEREZO LUIS JAVIER',
#    'CERTEZA COMPAÑIA DE SEGUROS SA',
#    'CERVANTES JOSE ROBERTO',
#    'CERVECERIA Y MALTERIA QUILMES S.A',
#    'CH ROBINSON WORLDWIDE ARGENTINA SA',
#    'CHAMORRO JOSE LUIS',
#    'CHECKING SA',
#    'CHEMTON SA',
#    'CHEN SHAOHONG',
#    'CHEN YUN',
#    'CHERMAN MARIA FERNANDA',
#    'CHERNIASVSKY ISIDORO',
#    'CHEVRON ARGENTINA SRL',
#    'CHIMEAL SRL',
#    'CHIODETTI AGOSTINA INES',
#    'CHITAME SA',
#    'CHOI JAE YONG',
#    'CHOI JUN AH',
#    'CHOIKUE SA',
#    'CHOREN EDUARDO',
#    'CHUBB ARG DE SEGUROS S.A.',
#    'CHUECA SOHO SRL',
#    'CIA ARG DE SEGUROS VICTORIA SA',
#    'CIA GLOBAL DE SERVICIOS SA',
#    'CIA INVERSORA LATINOAMERICANA',
#    'CIA. DE SERVICIOS AEROPORTUARIOS S.A.',
#    'CIA. ARGENTINA DE DISFRACES S.A.',
#    'CIA. DE SEGUROS LA MERCANTIL ANDINA S.A.',
#    'CIBA ESPECIALIADES QUIMICAS S.A.',
#    'CIBELLO JORGE LUCIANO',
#    'CICCHINELLI JACQUELINE ALICIA',
#    'CIGLIUTTI GUERINI S.A.',
#    'CILOVI SA',
#    'CIMA SA (GC)',
#    'CIMMINO HNOS SA',
#    'CINTREY SA',
#    'CIRCONS S.R.L.',
#    'CITIBANK NA',
#    'CITYTOYS SA',
#    'CIVINEXT S.A',
#    'CLANDESTINE SRL',
#    'CLAZON PIZURNO JUAN ALBERTO',
#    'CLEAN BAIRES S.A.',
#    'CLEANOSOL ARGENTINA SAICFI',
#    'CLEMENTE DE GARCIA NORMA SUSANA',
#    'CLEVERMAN SRL',
#    'CLIENTING GROUP SA',
#    'CLO CLO S.A.',
#    'CLOVER LOGISTICS SRL',
#    'CLUB MONSERRAT SA',
#    'CM DESARROLLOS INMOBILIARIOS ARG.SA',
#    'CMP ESTRUCTURAS SA',
#    'CNP ASSURANCES CIA DE SEGUROS SA',
#    'COAFI S.A.',
#    'COBENA SA',
#    'COCA COLA FEMSA BS AS',
#    'COCA COLA FEMSA DE BUENOS AIRES SA',
#    'CODECOP SRL',
#    'CODESFIL S.R.L.',
#    'CODI SA CONEVIAL SA UTE',
#    'COHEN ESTHER JACQUELINE',
#    'COLALAO DEL VALLE SA',
#    'COLISEO DE LAS CARNES S.R.L.',
#    'COLOMBO Y MAGLIANO SA',
#    'COLOMBRARO HNOS SCA',
#    'COLOPLAST DE ARGENTINA SA',
#    'COLTUR S.A.',
#    'COLZANI Y ASOCIADOS SA',
#    'COMENSE S.A.',
#    'COMERCIAL DE TURISMO S.A.',
#    'COMERCIALIZADORA BIDA S.R.L.',
#    'COMERCIALIZADORA BIDA SRL',
#    'COMERCIALIZADORA DE METALES PRECIOSOS S.A.',
#    'COMETAL ESTRUCTURAS S.A.',
#    'COMMIT IT SA',
#    "COMPAGNIE FRANCAISE D'ASSURANCE POUR LE COMMERCE EXTERIOR SUC. ARG.",
#    'COMPAÑIA ALIMENTOS NATURALES SA',
#    'COMPAÑIA DE CIERRES RRO SA',
#    'COMPAÑIA DE SEGUROS INSUR SA',
#    'COMPAÑIA GENERAL DE COMBUSTIBLES SA',
#    'COMPAÑIA GENERAL DE HACIENDA S.A.',
#    'COMPAÑIA SISTENSA S.R.L.',
#    'COMPART VIP SRL',
#    'COMPUTERS FRANCHISES SA',
#    'COMUNIDAD VIRTUAL SA',
#    'CON MOR SRL',
#    'CON TEC DES SA',
#    'CONDUFIL SRL',
#    'CONECTEAM S.R.L.',
#    'CONEXTUBE SA',
#    'CONFECCIONES SEMAN S.A.',
#    'CONFFUSSION S.A.',
#    'CONIDIA SA',
#    'CONLAT CONSTRUCCIONES LATINOAMERICANAS SA',
#    'CONMAN ARGENTINA SA',
#    'CONSTRUCCION DE VIVIENDA PARA LA ARMADA-COVIARA',
#    'CONSTRUCSUR S.R.L.',
#    'CONSTRUCTORA DEC S.A.',
#    'CONSTRUCTORA LUAL S.R.L.',
#    'CONSTRUCTORA MURO SA',
#    'CONSULTORA PORTAS SA',
#    'CONSULTORES ASOCIADOS ECOTRANS SA',
#    'CONSULTORES ASSETS MANAGEMENT SA',
#    'CONTEMAN SA',
#    'CONTINENTAL DO BRASIL',
#    'CONTINENTAL NETWIORK SRL',
#    'CONURBANO DISTRIBUCION SA',
#    'COOK MASTER SRL & EQUIS QUINCE S.A. UTE',
#    "COOK'S SRL",
#    'COOP. CREDIVICO DE CREDITO VIVIENDA Y CONSUMO LTDA',
#    'COOP. DE PROVISION LA PRENSA ARG LTDA',
#    'COOP. DE VIVIENDA CREDITO Y CONSUMO 20 DE JUNIO LTDA',
#    'COOPERATIVA 2001 DE VIVIENDA CREDITO Y CONSUMO',
#    'COOPERATIVA DE PROVISION Y SERVICIOS PARA EDUCADORES ESCUELA FISHBACH',
#    'COOPERATIVA DE SEGUROS LUZ Y FUERZA LTDA',
#    'COOPERATIVA DE TRABAJO DE SEG Y VIGILANCIA DOGO ARG',
#    'COOPERATIVA DE TRABAJO TAVERGUIS LTDA',
#    'COOPERATIVA DE TRABAJO VALVANERA LIMITADA',
#    'COPALUS SRL',
#    'COPROA',
#    'CORA DIR SA',
#    'CORDOBA GUILLERMINA FRANCISCA',
#    'CORINGRATO S.A.',
#    'CORNELL Y ASOCIADOS S.R.L.',
#    'CORONEL GUSTAVO SERGIO',
#    'CORPORACION CARNICA S.A.',
#    'CORPORACION LODRA SRL',
#    'CORPORACION RIBERA SUR SA',
#    'CORPORATE CORP SA',
#    'CORRALON LAPRIDA SRL',
#    'CORRAO HECTOR OSVALDO',
#    'CORRIENTES 1181 SA',
#    'CORRIENTES 1522 S.A.',
#    'CORVEN MOTORS ARGENTINA SA',
#    'CORVEN SACI',
#    'CORVETO SA',
#    'COR-VIAL SA',
#    'COSAS NUESTRAS SA',
#    'COSENA SEGUROS S.A.',
#    'COSMETICA ITALIANA SA',
#    'COSMETICOS ANGOSTURA S.A',
#    'COSTA EDGARDO Y GIARRIZZO LOPEZ RICARDO SH',
#    'COSTILLA MARCELA ANGELICA',
#    'COTECNA INSPECCION ARG. SA',
#    'COTO ALFREDO',
#    'CRAVERI SA',
#    'CREADIMA SRL',
#    'CREDENCIAL ARGENTINA SA',
#    'CREDIL SRL',
#    'CREDINAMICO SA',
#    'CRESKOTEC SA',
#    'CRESUD SACIF Y A',
#    'CRISTALES EBENOR SA',
#    'CRISTINA TERESA MIGUENS',
#    'CRIVALL S.A.',
#    'CRODA ARGENTINA SA',
#    'CROMOION S.R.L.',
#    'CRUZ SILVA JOSELITO HERMINIO',
#    'CUEROGRAS',
#    'CUEROS LA PAZ',
#    'CUEROS PORTEÑOS S.R.L.',
#    'CUNDIR SA',
#    'CUORE CONSUMER RESEARCH SA',
#    'CUPRUBELL S. A.',
#    'CURCIO ADALBERTO GABRIEL',
#    'CURITIBA SRL',
#    'CURTI MARCELO',
#    'CURTUME CBR SA',
#    'CUZZONI SIRO ESTEBAN',
#    'CYBER CALL SRL',
#    'CYCLELOGIC ARGENTINA SRL',
#    "D' AWACOR SRL",
#    'D C VIAJES Y TURISMO S.A.',
#    'D.G. PROYECTOS SA',
#    'D.G.BELGRANO SA',
#    'DABBAH DAN YOEL',
#    'DABBAH URIEL',
#    'DADAV SRL',
#    'DADE S.A.',
#    'DAGET S. A.',
#    'DAL SANTO INDUSTRIAL Y COMERCIAL S.A.',
#    'DALE CARLOS ALBERTO',
#    'DALTO FLAVIO ANIBAL',
#    'DANIEL MANENTI GABRIEL MANENTI SH',
#    'DASPENAS DAMIAN EDGARDO',
#    'DASSAULT SYSTEMES AMERICAS CORP.',
#    'DATANDHOME SUPPLIER SA',
#    'DATATECH SA',
#    'DATCO SA',
#    'DATEC ARGENTINA SA',
#    'DAVIS ALFREDO LUIS',
#    'DCLAS SRL',
#    'DE GENNARO ALEJANDRO PEDRO',
#    'DE LA TORRE, ALEJANDRO',
#    'DE LEVIE S.A.',
#    'DE MAIO, EDGARDO',
#    'DE YACOS SA',
#    'DECREDITO SA',
#    'DEFUEN S.A.',
#    'DEL PARQUE SHOPPING CENTER SA',
#    'DEL RETRO SALUD S.A.',
#    'DELGADO PINTOS IRMA',
#    'DELLA VECCHIA DISEGNI S.A.',
#    'DELLACHA JUAN PEDRO',
#    'DELTACAR SA',
#    'DELTACOM S.A.',
#    'DELUCA, JORGE ALONSO',
#    'DENO SA',
#    'DENVER FARMA SA',
#    'DERE EDISON',
#    'DEREVENCHA GRACIELA',
#    'DESAB S.A.',
#    'DESFA SRL.',
#    'DESIDERIO, LUIS ALBERTO',
#    'DESPEGAR.COM.AR SA',
#    'DESSE, JOSE',
#    'DESTEL S.A.',
#    'DEVA´S SA',
#    'DHL EXPRESS (ARG) SA',
#    'DI PILATO, DOMINGO',
#    'DIA ARGENTINA SA',
#    'DIAPIN SA',
#    'DIAZ HUGO JUAN',
#    'DIAZ LESTREM MARTIN',
#    'DIAZ RIGANTI CEREALES SRL',
#    'DIBUTEC PROYECTOS Y CONSTRUCCIONES S.A.',
#    'DIEGO ARIEL KOGUTEK',
#    'DIGITAL MC S.A.',
#    'DIMARCOMP S.A.',
#    'DINATECH S.A.',
#    'DINAVOX SRL.',
#    'DING BO',
#    'DIRECCION GENERAL DE FABRICACIONES MILITARES',
#    'DIRECTV ARGENTINA S.A.',
#    'DISCO PRO INTERNATIONALS SA',
#    'DISEÑOS DEPORTIVOS SRL',
#    'DISIPAR S.A',
#    'DISTOTAL S.R.L.',
#    'DISTRIBUIDORA AMERICANA DE PUBLICACIONES S.R.L.',
#    'DISTRIBUIDORA AZUL S.A',
#    'DISTRIBUIDORA BLUMEN SA',
#    'DISTRIBUIDORA DE GAS DEL CENTRO S.A.',
#    'DISTRIBUIDORA EL CRIOLLO SRL',
#    'DISTRIBUIDORA UNICLIMA S.R.L.',
#    'DISTRISUR ARGENTINA SA',
#    'DITOYS S.A.',
#    'DIVOT GROUP SA',
#    'DIWAN - FUCCI PRODUCCIONES ARTISTICAS SA',
#    'DIXEY SA',
#    'DO CAMPO ANTONIO',
#    'DOIO SRL',
#    'DON VICTORIANO SRL',
#    'DONATO, DUILIO',
#    'DOTI, ANA LAURA Y OTRO',
#    'DOW AGROSCIENCES ARGENTINA SA',
#    'DRAGONAIR S.A.',
#    'DRAWER SA',
#    'DREAM AUTOADHESIVOS S.A.',
#    'DROGUERIA COMARSA SA',
#    'DROGUERIA LIBERTAD S.A.',
#    'DROGUERIA VARADERO S.A.',
#    'DROSER SA',
#    'DU PRE TEXTIL SRL',
#    'DYBELCORP S.A.',
#    'DYPSA DESARROLLOS Y PROYECTOS SA',
#    'DYSJOR SACI',
#    'E- PROFITS SRL',
#    'EASTEL S.A.',
#    'EDIFICADORA JAMIC S.R.L.',
#    'EDUVIPA SA',
#    'EDYKING SA',
#    'EFE 2 PRODUCCIONES SRL',
#    'EIDEM ROMINA ERIKA',
#    'EL CARDO RUSO SA',
#    'EL CARMEN SA',
#    'EL COMERCIO CIA DE SEGUROS A PRIMA FIJA S.A.',
#    'EL FUNDADOR S.A.',
#    'EL GALGO SACIF',
#    'EL GOL CONSTITUCION SA',
#    'EL MAESTRO GOURMET S.A.',
#    'EL MUELLE 2010 S.A.',
#    'EL POBRE LUIS S.H.',
#    'EL PROGRESO SEGUROS SA',
#    'EL SALVADOR 4040 SA',
#    'EL SURCO COMPAÑIA DE SEGUROS SA',
#    'ELABORADO S.A.',
#    'ELASKAR FEDERICO',
#    'ELECTRO CORPO SRL',
#    'ELECTRO DIESEL OLIDEN S.A.',
#    'ELECTROFUEGUINA S.A.',
#    'ELECTRONIC SYSTEM SA',
#    'ELEX SA',
#    'ELSE SA',
#    'EMBELL ARGENTINA S.A.',
#    'EMEJOTA TELECOMUNICACIONES SA',
#    'EMERGENCIAS ARTISTICAS SRL',
#    'EMISARIOS S.R.L.',
#    'EMPRENDIMIENTOS HOW WENS SRL',
#    'EMPRESA DE TRANSPORTE DON PEDRO SRL',
#    'ENAMA SA',
#    'ENCALADA BLANCO S.A.',
#    'ENERGIT ELECTRONICA DE POTENCIA S.A.',
#    'ENGRAMA SA',
#    'ENRIQUE ZENI Y CIA SA',
#    'ENRIQUEZ PABLO RUBEN',
#    'ENTA TGA S.R.L.',
#    'ENTRE RIOS 415 SRL',
#    'ENVASES DEL PLATA S.A.',
#    'E-PAYMENTS SA',
#    'EQUICENTER S.R.L',
#    'EQUIPAMIENTOS DUOMO SA',
#    'ERASMO SACI',
#    'ERGAS RICARDO SALOMON',
#    'ERLICH SILVIA LEONOR',
#    'ERNESTO VAZQUEZ Y FRANCISCO VAZQUEZ SRL',
#    'ESCOBAR HECTOR HORACIO',
#    'ESCUDOS SEGUROS S.A.',
#    'ESEKA SA',
#    'ESPACIO KS S.A.',
#    'ESPECIAS RAFAEL CANO SA',
#    'ESPLASINT SRL',
#    'ESPLUGA SA',
#    'ESSENTIAL S.A.',
#    'ESTABLECIMIENTO ELAN SA',
#    'ESTABLECIMIENTO GRAFICO VULCANO',
#    'ESTABLECIMIENTOS RIO GRANDE SA',
#    'ESTACION LIMA SA',
#    'ESTELAR SAN LUIS S.A.',
#    'ESTUDIO BERETTA GALARCE SRL',
#    'ESTUDIO MARTINEZ Y ASOCIADOS SRL',
#    'ETIQUETA BLANCA S.A.',
#    'ETUA SRL',
#    'EURO FOOD ARGENTINA SA',
#    'EURO LATINO S.A.',
#    'EUROAGUA SA',
#    'EUROFARMA ARG',
#    'EUROLAB SA',
#    'EVA S.A.',
#    'EXCELENCIA AUTOMOTRIZ S.A.',
#    'EXO S.A.',
#    'EXPOBAIRES S.A.',
#    'EXPOBLANC SRL',
#    'EXTRA POWER S.A.',
#    'EXTRUCER S.A.',
#    'F & C MOTORS SRL',
#    'F.M. TRAVEL SRL',
#    'FA GRUOP S.A.',
#    'FABRITAM SRL',
#    'FACTORIA AUTOPRTISTA SA',
#    'FAG SISTEMS S.A.',
#    'FAGRA SA',
#    'FAIRCO S.A.',
#    'FAMET AGRUP DE COLAB. EMP.',
#    'FARIAS MIRTA SUSANA',
#    'FARMACIA NUEVA LACROZE SRL',
#    'FARMANET S.A.',
#    'FAUR, MARCELO HORACIO',
#    'FEBICOM S.A.',
#    'FECA SRL',
#    'FEDCAR S.R.L.',
#    'FEDEICOMISO BALBIN 2409',
#    'FEDERACION PATRONAL SA',
#    'FEDERAL SERVICE SRL',
#    'FEG ENTRETENIMIENTOS S.A.',
#    'FEIJOO, HECTOR DANIEL',
#    'FEIMPORT SA',
#    'FEIT Y OLIVARI SA',
#    'FENG TAI S.A.',
#    'FERIAS ARGENTINAS SA',
#    'FERNANDEZ CARLOS ENRIQUE',
#    'FERNANDEZ JUAN',
#    'FERNANDEZ, NESTOR',
#    'FERRARO ROMINA',
#    'FERROSUR S.A.',
#    'FERRYTOR SRL',
#    'FIANZAS Y CREDITO SA',
#    'FIAT AUTO ARGENTINA S.A.',
#    'FID. CAMARONES 3568',
#    'FIDANZATO SA',
#    'FIDECOMISO NAZARRE 2775',
#    'FIDEICOM. AL COSTO DELGADO 577',
#    'FIDEICOMISO FINANCIERO AGROFINA II',
#    'FIDEICOMISO QUANTUM PALERMO',
#    'FIDEICOMISO VIRREY DEL PINO 4130',
#    'FIDRELLI, ANTONIO MARTIN',
#    'FIGUEROA FRANCISCO RAUL',
#    'FILELLA GUSTAVO',
#    'FILIPELLI SALAZAR GUSTAVO RODOLFO',
#    'FILIPONI ADOLFO',
#    'FINAL DE TELA SA',
#    'FINLINA S.A',
#    'FINTA SA',
#    'FINTA PELLE S.R.L.',
#    'FIRENZE VIAJES SRL',
#    'FIRST DATA CONO SUR SRL',
#    'FLEP SRL',
#    'FLOOR CLEAN SRL',
#    'FLORES OROSCO ALBERTINA',
#    'FLORES OSVALDO FERNANDO',
#    'FLORES, JOSE ALFREDO',
#    'FLUOR ARGENTINA INC',
#    'FOOD CO SA',
#    'FOOD´S LAND S.A.',
#    'FORCOR SA',
#    'FOREST CAR SA',
#    'FORTIN MAURE SA',
#    'FORVIS S.R.L.',
#    'FRANQUICIAS CLANDESTINE S.A.',
#    'FRANQUIMAR S.A.',
#    'FRATELLI AVERSA SA',
#    'FRAVEGA SA',
#    'FREITAS VIRGINIA MARIA',
#    'FRICARNESPAT SA',
#    'FRIENDS SRL',
#    'FRIGORIFICO CARDENAS SRL',
#    'FRIGORIFICO GRAL PAZ S.A.',
#    'FRIGORIFICO PENTA SA',
#    'FRIGORIFICO SAGA SAICYA.',
#    'FRIGORIFICO SUDESTE S.A.',
#    'FRIGORIFICO Y MATADERO CHIVILCOY S.A.',
#    'FRILOBOS SA',
#    'FRIMSA SA',
#    'FRIOLIM SA',
#    'FRISCIA DANIEL OSVALDO',
#    'FRONTERA LIVING SA',
# ...
#    'GENERAL PASTIC CORP SA',
#    'GENERALLI ARGENTINA CIA DE SEGUROS SA',
#    'GEO CONSTRUCCIONES SA',
#    'GERSZUNY JAIME SRL',
#    'GESTION FINANCIERA SA',
#    'GESTIONES SIDERURGICAS SRL',
#    'GIAMPAOLETTI SA',
#    'GIGIANTO IMPRESOS SRL',
#    'GIJON SA',
#    'GILABERT HUMBERTO ANTONIO',
#    'GIMENEZ LUIS OSVALDO',
#    "GIMO'S SA (SCE)",
#    'GIOIOSA OSCAR ALBERTO',
#    'GIORGETTI BARBARA',
#    'GIORGIO CANETTI SRL',
#    'GIZIRIAN EDUARDO',
#    'GLAUBERMAN ELOY ADRIAN',
#    'GLOBAL CEREALES SA',
#    'GLOBAL EQUITY SOCIEDAD DE BOLSA SA',
#    'GLOBAL FARM SA',
#    'GLOBAL TECH SA',
#    'GLORIAS DE LA BOCA SRL',
#    'GO SHOP SA',
#    'GOBBI NOVAG SA',
#    'GOLDY SRL',
#    'GOMERIAS NEUMEN S.A.',
#    'GOMEZ, GUSTAVO R.',
#    'GOMILA EXEQUIEL LUIS',
#    'GONZALEZ DIEGO FERNANDO',
#    'GONZALEZ GERARDO DANIEL',
#    'GONZALEZ GUSTAVO',
#    'GONZALEZ NORBERTO',
#    'GORGANCHIAN DORA MARIA',
#    'GORSKI ELENA Y LASAGNA ANTONELLA SH',
#    'GOU YANHUI',
#    'GPS SERVICIOS SA (G.C.)',
#    'GRABEAL MATERIALES ELECTRICOS S.A.',
#    'GRACE CAFE S.A.',
#    'GRAFICA ALSINA 999 SRL',
#    'GRAFICASE SRL',
#    'GRAMAJO EDGARDO JAVIER',
#    'GRAN RUBIA S.A.',
#    'GRANJA CLAUDIO',
#    'GRAPH MAKERS S.A.',
#    'GRAPHIC CENTER S.A.',
#    'GRAVAFILT S.A.',
#    'GRECO ALDO MARIO',
#    'GRILLO CAROLINA SOLEDAD',
#    'GRIMOLDI SA',
#    'GRIPPO MARIA E.',
#    'GROSSO ARRAZTOA JUAN JOSE',
#    'GROUPALIA SRL',
#    'GRUPO COLONIA SA',
#    'GRUPO LE TACO SA.',
#    'GRUPO LEGAR',
#    'GRUPO MOBILE SA',
#    'GRUPO SUPERVIELLE S.A.',
#    'GRUPO TEAMSEG SA',
#    'GRUPO TRESNAL SRL',
#    'GRUPPO ARUBA SRL',
#    'GRYCORP S.A',
#    'GTE SRL',
#    'GUAGNINI HECTOR ARTURO',
#    'GUELETAZO SRL',
#    'GUIDO JOEL WAINSTEIN',
#    'GUILLER, PABLO GUSTAVO',
#    'GUSTAVO WENGROVSKI',
#    'H TRIMARCHI SRL',
#    'H5 SA',
#    'HADIDA NORA ADELA SANDRA',
#    'HAIR SYSTEM S.A.',
#    'HAKUS SRL',
#    'HAMRA FEDERICO SADEK',
#    'HANG BONG LIM',
#    'HANSEATICA COMPAÑIA DE SEGUROS S.A.',
#    'HAPPENING SA',
#    'HARD BAR SA',
#    'HAVANNA S.A.',
#    'HE HUAJIN',
#    'HEGUY HNOS Y CIA SACA',
#    'HELACOR SA',
#    'HELIOS PHARMA S.A.',
#    'HIERROS TORRENT S.A.',
#    'HILANDERIA CAPEN SA',
#    'HILANDERIA IBERICO ARGENTINA S.A.',
#    'HILOS COSEFIL S.A.',
#    'HIPERCUBO SA',
#    'HOCHSCHID MINING ARGENTINA CORPORATION SA',
#    'HOLLEN AG LTDA S.R.L.',
#    'HONDA MOTOR ARGENTINA SA',
#    'HORECA SRL',
#    'HOTEL PRESIDENTE SA',
#    'HOURQUESCOS CECILIA',
#    'HSBC BANK ARGENTINA SA',
#    'HSBC SEGUROS DE RETIRO ARG.SA',
#    'HSBC SEGUROS DE VIDA ARGENTINA SA',
#    'HSIE HSIU HSING',
#    'HT FOOD S.R.L.',
#    'HTS AR SA',
#    'HUA FENG',
#    'HUANG PINGHUA',
#    'HUAWEI INVESTMENT CO LTD',
#    'HUSNI, EDUARDO G.',
#    'IARAI SA',
#    'IBERO ASISTENCIA SA',
#    'IBM ARGENTINA',
#    'ICON ARGENTINA SA',
#    'IDEAMODA SRL',
#    'IECSA SA',
#    'IELE DANIEL HUGO',
#    'IGAR SRL',
#    'IGLYS SOCIEDAD ANONIMA',
#    'IMANUEL TEXTIL S.R.L.',
#    'IMPETU BISTRO SRL',
#    'IMPLANTES CLP SRL',
#    'IMPORT MUSIC ARGENTINA SA',
#    'IMPUS SRL',
#    'IN.SAN SRL',
#    'INARCO SRL',
#    'INDAGA S.A.',
#    'INDELMEC S. A.',
#    'INDESIT ARGENTINA S.A.',
#    'INDUS JEANS S.A.',
#    'INDUSNOR S.A.',
#    'INDUSTRIA AGROGANADERA DEL OESTE SA',
#    'INDUSTRIA ALGOVADAM SA',
#    'INDUSTRIAS CECCONI SRL',
#    'INDUSTRIAS METALURGICAS DE SAN NICOLAS SRL',
#    'INDUSTRIAS METALURGICAS HALPERIN S.A.',
#    'INFOMEDICAL S.A.',
#    'INFORMATICA FUEGUINA',
#    'INGENIEROS MACCARONE S.A.',
#    'INGEPLAM S.A',
#    'INNOCENZA S.A.',
#    'INNOVATION AND COMPANY SRL',
#    'INOVATECH ARGENTINA S.A.',
#    'INSTITUTO ASEGURADOR MERCANTIL CIA ARG DE SEGUROS SA',
#    'INSTITUTO DE ASISTENCIA PRIVADA S.A.',
#    'INSTITUTO DE SEGUROS SA',
#    'INSTRUMENTOS Y COMANDOS SA',
#    'INSUMA SRL',
#    'INSUMOS AGROQUIMICOS SA',
#    'INTAGRO SA',
#    'INTECO ARGENTINA S.R.L.',
#    'INTEGRITY SEGUROS ARGENTINA S.A.',
#    'INTER ROP SRL',
#    'INTERACCION ART SA',
#    'INTERACCION SEG SA',
#    'INTERBURO SRL',
#    'INTEROPTICS S.A.',
#    'INTERSERVIT SRL',
#    'INTERSOFT SA',
#    'INVENSYS PROCESS SYSTEM ARG. SA',
#    'INVERNOZ JUAN CARLOS',
#    'INVERSIONES Y EMPRENDIMIENTOS REALIZAR SA',
#    'INVERSORA M&S SA',
#    'IPMAG SA',
#    'IRB BRASIL RESSEGUROS SA EN FORMACION',
#    'ISEAS HUGO DANIEL',
#    'ISOLUX COISAN ENERGIAS RENOVABLES SA',
#    'ISOLUX INGENIERIA S.A.',
#    'ISOTECH S.R.L.',
#    'ISP ARGENTINA SRL',
#    'ISSEL HUGO ALBERTO',
#    'ISSITEX SRL',
#    'IT DEALS SA',
#    'ITHURRALDE LAURA BEATRIZ',
#    'ITURAM DE ARGENTINA S.A.',
#    'J CARTELLONE CC SA',
#    'J CARTELLONE CC SA - ELEPRINT SA UTE',
#    'J CARTELLONE CC SA - INSOLUX ING SA UTE',
#    'J S MEDICINA ELECTRONICA SRL',
#    'J Y G KIDS SRL',
#    'JABALI SA',
#    'JACOBO SZWOM E HIJOS SA',
#    'JAG CONSULTORES Y ASOCIADOS S.A.',
#    'JAKIM DIANA MABEL ZORAIDA',
#    'JAKIM EDUARDO',
#    'JAMES SMART SA',
#    'JAMM SRL',
#    'JANSSEN CILAG FARMACEUT. SA',
#    'JAS DISEÑO SA',
#    'JAVAIA S.A.',
#    'JAVIDER S.A.',
#    'JED SA',
#    'JET CUSTOM S.A.',
#    'JL TRIVIÑO BRIALES SA IFC SA OCSA SA UTE',
#    'JONES LANG LASALLE SRL',
#    'JONTE 3386 SRL',
#    'JORGE TOLOSA SA',
#    ...],
#   'FECHA_INICIO': ['01/10/2014',
#    '27/03/2015',
#    '23/12/2013',
#    'N/L',
#    '09/02/2015',
#    '25/09/2014',
#    '28/04/2015',
#    '30/12/2014',
#    '30/03/2015',
#    '05/10/2010',
#    '20/11/2014',
#    '29/10/2014',
#    '22/09/2015',
#    '14/01/2015',
#    '28/04/2014',
#    '16/06/2015',
#    '08/01/2013',
#    '24/06/2015',
#    '22/07/2015',
#    '06/01/2014',
#    '18/09/2015',
#    '17/09/2015',
#    '10/06/2015',
#    '29/12/2014',
#    '25/04/2013',
#    '16/10/2014',
#    '21/11/2014',
#    '03/09/2015',
#    '21/08/2014',
#    '26/01/2015',
#    '27/07/2015',
#    '09/09/2014',
#    '06/05/2015',
#    '27/04/2015',
#    '23/02/2015',
#    '14/09/2015',
#    '05/01/2015',
#    '19/11/2014',
#    '08/05/2015',
#    '23/09/2015',
#    '28/09/2015',
#    '08/10/2013',
#    '27/08/2015',
#    '15/06/2015',
#    '05/08/2015',
#    '09/02/2012',
#    '01/07/2015',
#    '21/08/2015',
#    '15/10/2014',
#    '06/06/2015',
#    '18/08/2015',
#    '17/10/2014',
#    '05/03/2015',
#    '08/09/2015',
#    '05/05/2015',
#    '24/09/2014',
#    '28/07/2015',
#    '15/05/2015',
#    '03/03/2015',
#    '12/08/2015',
#    '22/07/2014',
#    '30/06/2014',
#    '20/05/2015',
#    '19/03/2015',
#    '16/04/2015',
#    '23/01/2014',
#    '03/02/2014',
#    '14/05/2014',
#    '22/10/2014',
#    '21/09/2015',
#    '27/05/2015',
#    '21/07/2015',
#    '20/01/2015',
#    '28/09/2014',
#    '18/05/2011',
#    '05/08/2014',
#    '16/07/2015',
#    '14/08/2014',
#    '19/03/2014',
#    '18/03/2015',
#    '08/06/2015',
#    '26/02/2015',
#    '22/06/2015',
#    '22/01/2009',
#    '03/11/2014',
#    '24/07/2015',
#    '14/07/2015',
#    '29/01/2015',
#    '19/07/2013',
#    '23/10/2014',
#    '03/08/2015',
#    '17/03/2014',
#    '26/01/2012',
#    '16/01/2015',
#    '25/06/2015',
#    '16/03/2011',
#    '28/07/2010',
#    '20/03/2015',
#    '23/12/2014',
#    '29/04/2015',
#    '22/08/2014',
#    '13/07/2015',
#    '29/09/2011',
#    '07/09/2015',
#    '03/09/2014',
#    '17/06/2014',
#    '20/04/2015',
#    '06/11/2014',
#    '22/12/2014',
#    '16/03/2015',
#    '24/06/2014',
#    '02/09/2014',
#    '04/02/2015',
#    '13/11/2013',
#    '01/02/2013',
#    '05/02/2015',
#    '05/02/2014',
#    '07/01/2015',
#    '11/02/2015',
#    '11/03/2014',
#    '29/09/2015',
#    '25/08/2015',
#    '04/08/2014',
#    '19/06/2015',
#    '15/09/2015',
#    '15/07/2015',
#    '14/03/2014',
#    '23/06/2015',
#    '26/06/2015',
#    '23/07/2013',
#    '03/07/2014',
#    '17/07/2013',
#    nan,
#    '05/09/2014',
#    '16/02/2012',
#    '22/02/2012',
#    '21/05/2015',
#    '30/06/2015',
#    '06/09/2013',
#    '27/11/2014',
#    '29/05/2014',
#    '12/11/2014',
#    '26/06/2014',
#    '07/07/2015',
#    '26/08/2014',
#    '31/07/2013',
#    '13/08/2014',
#    '16/12/2014',
#    'SIN INICIO',
#    '27/06/2014',
#    '30/09/2014',
#    '05/11/2013',
#    '09/06/2014',
#    '14/05/2015',
#    '24/10/2014',
#    '30/04/2015',
#    '24/09/2015',
#    '03/06/2015',
#    '21/10/2014',
#    '24/01/2014',
#    '15/01/2015',
#    '21/04/2015',
#    '09/01/2015',
#    '22/01/2015',
#    '08/09/2014',
#    '25/03/2015',
#    '07/08/2015',
#    '11/08/2015',
#    '25/08/2014',
#    '31/01/2014',
#    '08/07/2015',
#    '10/07/2015',
#    '19/08/2015',
#    '12/06/2013',
#    '14/01/2014',
#    '18/12/2014',
#    '16/09/2015',
#    '07/05/2015',
#    '06/08/2014',
#    '26/03/2014',
#    '12/05/2015',
#    '04/05/2015',
#    '31/08/2015',
#    '12/05/2008',
#    '10/04/2015',
#    '02/09/2015',
#    '28/01/2014',
#    '26/05/2010',
#    '07/10/2013',
#    '10/02/2015',
#    '30/07/2014',
#    '07/04/2015',
#    '24/04/2015',
#    '22/03/2013',
#    '26/09/2014',
#    '23/07/2015',
#    '11/08/2014',
#    '01/06/2012',
#    '08/10/2014',
#    '26/08/2015',
#    '29/07/2015',
#    '21/01/2015',
#    '28/08/2015',
#    '01/09/2014',
#    '08/04/2014',
#    '10/09/2014',
#    '09/09/2015',
#    '11/05/2015',
#    '16/04/2014',
#    '17/12/2014',
#    '24/08/2015',
#    '01/06/2015',
#    '06/02/2015',
#    '02/07/2015',
#    '23/04/2013',
#    '12/08/2013',
#    '06/03/2014',
#    '09/05/2014',
#    '20/08/2015',
#    '15/04/2015',
#    '02/03/2015',
#    '19/01/2015',
#    '23/09/2014',
#    '04/06/2015',
#    '28/10/2014',
#    '04/11/2014',
#    '24/07/2014',
#    '29/08/2013',
#    '19/01/2012',
#    '24/02/2014',
#    '03/02/2015',
#    '26/03/2015',
#    '29/08/2014',
#    '30/01/2015',
#    '13/07/2012',
#    '08/01/2015',
#    '13/02/2014',
#    '14/09/2009',
#    '13/05/2015',
#    '06/07/2012',
#    '22/05/2014',
#    '02/06/2015',
#    '01/09/2015',
#    '21/07/2014',
#    '01/04/2015',
#    '07/10/2014',
#    '03/07/2012',
#    '30/04/2014',
#    '18/07/2014',
#    '07/02/2014',
#    '23/04/2015',
#    '12/11/2013',
#    '21/11/2012',
#    '12/03/2014',
#    '10/10/2013',
#    '01/12/2014',
#    '27/08/2014',
#    '28/05/2015',
#    '24/02/2015',
#    '25/09/2015',
#    '30/09/2015',
#    '18/11/2014',
#    '15/08/2014',
#    '19/09/2013',
#    '13/04/2015',
#    '26/05/2015',
#    '12/03/2015',
#    '04/08/2015',
#    '26/11/2013',
#    '12/06/2015',
#    '10/11/2014',
#    '07/07/2014',
#    '17/07/2015',
#    '04/03/2015',
#    '12/07/2007',
#    '11/09/2013',
#    '17/11/2014',
#    '07/01/2014',
#    '29/06/2015',
#    '31/07/2011',
#    '26/03/2012',
#    '31/03/2014',
#    '05/11/2014',
#    '29/06/2012',
#    '08/11/2013',
#    '29/04/2014',
#    '14/08/2015',
#    '03/02/2012',
#    '30/07/2015',
#    '02/10/2009',
#    '04/03/2013',
#    '15/12/2014',
#    '12/01/2015',
#    '18/06/2015',
#    '19/12/2013',
#    '16/01/2014',
#    '11/06/2015',
#    '17/01/2014',
#    '27/01/2015',
#    '04/09/2015',
#    '15/04/2014',
#    '19/05/2015',
#    '20/08/2014',
#    '16/03/2012',
#    '10/01/2014',
#    '17/12/2013',
#    '20/07/2015',
#    '29/05/2015',
#    '26/11/2014',
#    '11/04/2014',
#    '09/10/2013',
#    '17/03/2015',
#    '29/06/2011',
#    '28/11/2014',
#    '27/02/2015',
#    '29/01/2014',
#    '01/08/2014',
#    '09/08/2011',
#    '25/06/2014',
#    '13/03/2015',
#    '06/07/2015',
#    '20/10/2014',
#    '11/06/2014',
#    '27/04/2012',
#    '06/02/2014',
#    '25/10/2013',
#    '20/02/2015',
#    '11/02/2014',
#    '02/02/2015',
#    '25/07/2013',
#    '21/05/2014',
#    '16/07/2010',
#    '19/12/2014',
#    '10/08/2015',
#    '22/09/2014',
#    '14/06/2011',
#    '16/01/2013',
#    '03/07/2015',
#    '03/12/2014',
#    '22/07/2013',
#    '28/02/2014',
#    '13/08/2015',
#    '16/06/2014',
#    '28/08/2014',
#    '05/06/2015',
#    '18/05/2015',
#    '15/11/2012',
#    '05/03/2014',
#    '14/04/2015',
#    '25/07/2014',
#    '13/01/2015',
#    '09/01/2014',
#    '14/01/2009',
#    '15/10/2015',
#    '18/10/2013',
#    '23/01/2015',
#    '28/04/2010',
#    '11/11/2014',
#    '24/04/2014',
#    '18/04/2014',
#    '10/06/2014',
#    '20/01/2014',
#    '18/09/2014',
#    '23/04/2014',
#    '17/01/2013',
#    '12/02/2012',
#    '13/11/2014',
#    '18/02/2014',
#    '13/01/2014',
#    '23/08/2013',
#    '02/07/2014',
#    '15/08/2013',
#    '13/06/2014',
#    '22/04/2015',
#    '10/02/2014',
#    '18/09/2013',
#    '28/01/2015',
#    '31/03/2015',
#    '20/02/2014',
#    '27/10/2014',
#    '19/11/2013',
#    '22/01/2014',
#    '30/01/2013',
#    '04/04/2014',
#    '06/04/2015',
#    '28/07/2014',
#    '12/06/2014',
#    '06/08/2015',
#    '08/04/2015',
#    '07/03/2014',
#    '11/03/2015',
#    '04/09/2014',
#    '06/01/2015',
#    '22/05/2015',
#    '04/03/2011',
#    '30/10/2014',
#    '10/12/2013',
#    '12/02/2015',
#    '23/06/2011',
#    '10/03/2014',
#    '20/08/2013',
#    '06/03/2015',
#    '03/05/2012',
#    '06/10/2014',
#    '28/05/2014',
#    '11/09/2015',
#    '30/12/2010',
#    '13/03/2008',
#    '17/06/2015',
#    '23/10/2013',
#    '21/10/2015',
#    '08/07/2014',
#    '16/10/2013',
#    '29/07/2014',
#    '16/08/2013',
#    '04/07/2013',
#    '09/04/2015',
#    '11/11/2013',
#    '25/03/2014',
#    '11/12/2012',
#    '11/12/2014',
#    '23/06/2014',
#    '03/04/2014',
#    '27/02/2014',
#    '10/09/2015',
#    '10/08/2013',
#    '22/04/2013',
#    '21/01/2014',
#    '12/11/2012',
#    '19/06/2009',
#    '20/03/2014',
#    '19/05/2014',
#    '18/04/2012',
#    '12/07/2013',
#    '02/10/2014',
#    '01/08/2013',
#    'NO LOCALIZADO',
#    '06/08/2013',
#    '04/07/2015',
#    '01/11/2014',
#    '03/06/2014',
#    '04/02/2014',
#    '29/09/2014',
#    '30/01/2014',
#    '19/08/2014',
#    '09/06/2015',
#    '28/08/2013',
#    '18/02/2015',
#    '23/05/2014',
#    '25/02/2015',
#    '09/01/2013',
#    '16/09/2014',
#    '15/01/2014',
#    '01/07/2014',
#    '13/02/2015',
#    '25/11/2014',
#    '26/05/2014',
#    '17/04/2015',
#    '22/05/2013',
#    '23/09/2013',
#    '29/08/2015',
#    '03/08/2012',
#    '26/12/2013',
#    '05/02/2013',
#    '22/04/2014',
#    '07/05/2012',
#    '27/12/2011',
#    '19/02/2015',
#    '02/06/2014',
#    '30/05/2015',
#    '04/12/2012',
#    '31/07/2015',
#    '21/03/2014',
#    '29/05/2012',
#    '08/08/2013',
#    '17/02/2012',
#    '12/03/2012',
#    '08/01/2014',
#    '22/02/2015',
#    '07/11/2014',
#    '18/07/2013',
#    '23/07/2014',
#    '21/03/2012',
#    '07/02/2011',
#    '30/06/2011',
#    '28/04/2008',
#    '26/08/2008',
#    '06/05/2014',
#    '12/12/2014',
#    '13/09/2013',
#    '05/08/2013',
#    '30/05/2014',
#    '17/07/2012',
#    '12/07/2012',
#    '13/12/2013',
#    '01/04/2014',
#    '07/05/2014',
#    '12/01/2012',
#    '08/08/2014',
#    '31/10/2014'],
#   'FECHA_DEVOL_TRANSF': [nan,
#    '19/08/2015',
#    '22/05/2014',
#    '28/09/2012',
#    '08/01/2013',
#    '20/08/2015',
#    '01/06/2015',
#    '18/05/2015',
#    '18/08/2015',
#    '10/09/2015',
#    'TRANSFERENCIA',
#    '27/08/2015',
#    '11/07/2014',
#    '23/04/2015',
#    '10/12/2014',
#    '03/02/2015',
#    '21/08/2015',
#    '12/08/2015',
#    '10/07/2015',
#    '19/03/2015',
#    '29/07/2014',
#    '10/04/2015',
#    '08/07/2014',
#    '21/05/2015',
#    '13/02/2015',
#    '05/09/2014',
#    '20/07/2014',
#    '26/02/2015',
#    '24/07/2015',
#    '02/12/2013',
#    '02/07/2015',
#    '12/03/2014',
#    '07/08/2015',
#    '09/10/2014',
#    '16/04/2014',
#    '05/05/2014',
#    '25/11/2014',
#    '02/12/2014',
#    '22/09/2015',
#    '07/04/2015',
#    '01/07/2015',
#    'DEVOLUCION',
#    '02/06/2015',
#    '17/03/2014',
#    '23/10/2014',
#    '20/03/2015',
#    '01/02/2015',
#    '08/04/2015',
#    '24/04/2015',
#    '15/10/2014',
#    '03/12/2014',
#    '24/09/2015',
#    '21/09/2015',
#    '04/08/2015',
#    '28/08/2015',
#    '26/11/2014',
#    '12/05/2014',
#    '01/08/2012',
#    '12/06/2015',
#    '06/04/2015',
#    '01/12/2014',
#    '22/01/2015',
#    '10/02/2015',
#    '17/02/2015',
#    '01/08/2014',
#    '13/04/2015',
#    '04/06/2013',
#    '15/01/2015',
#    '02/09/2015',
#    '12/03/2015',
#    '11/08/2014',
#    '09/04/2014',
#    '16/09/2015',
#    '10/08/2015',
#    '22/09/2014',
#    '30/06/2015',
#    '25/02/2015',
#    '26/05/2015',
#    '21/07/2015',
#    '09/12/2014',
#    '27/04/2015',
#    '15/06/2015',
#    '14/07/2015',
#    '11/06/2015',
#    '26/06/2015',
#    '09/09/2014',
#    '02/09/2014',
#    '15/07/2015',
#    '05/11/2014',
#    '13/08/2013',
#    '16/05/2014',
#    '16/07/2015',
#    '17/09/2013',
#    '01/09/2015',
#    '29/04/2015',
#    '07/01/2014',
#    '28/04/2015',
#    '30/07/2015',
#    '23/02/2015',
#    '21/10/2015',
#    '19/11/2013',
#    '17/09/2015',
#    '17/03/2015',
#    '10/07/2014',
#    '15/04/2015',
#    '13/08/2014',
#    '25/03/2014',
#    '16/07/2013',
#    '16/12/2013',
#    '24/06/2015',
#    '24/04/2014',
#    '18/06/2015',
#    '20/05/2015',
#    '22/04/2015',
#    '14/10/2014',
#    '01/11/2014',
#    '04/05/2015',
#    '18/03/2015',
#    '03/06/2015',
#    '19/06/2015',
#    '11/07/2012',
#    '28/09/2015',
#    '31/08/2015',
#    '21/08/2014',
#    '11/09/2015',
#    '05/05/2015',
#    '15/09/2014',
#    '07/09/2015',
#    '23/09/2014',
#    '13/07/2015',
#    '29/09/2014',
#    '21/05/2014',
#    '10/06/2015',
#    '23/09/2015',
#    '14/04/2015',
#    '23/06/2015',
#    '19/02/2015',
#    '06/02/2015',
#    '04/08/2014',
#    '04/09/2014',
#    '12/02/2015',
#    '20/07/2015',
#    '01/03/2015',
#    '09/09/2015',
#    '13/05/2015',
#    '06/05/2014',
#    '13/08/2015',
#    '18/09/2013']}}

# %% [markdown]
# ### Verificaciion ortografia española de los valores

# %%
# Para analizar la ortografía en español de las columnas se puede usar la siguiente función e instalar la librería fuzzywuzzy

import sys
print(sys.path)


import re
from fuzzywuzzy import fuzz


def ortografia_columnas(df):
    columnas = df.columns
    columnas = [re.sub(r'[^a-zA-Z0-9 ]', '', columna) for columna in columnas]
    columnas = [columna.lower() for columna in columnas]
    columnas = [columna.replace(' ', '') for columna in columnas]
    columnas = [columna for columna in columnas if columna != '']
    columnas = list(set(columnas))
    ortografia = []
    for columna in columnas:
        if fuzz.ratio(columna, 'año') < 90:
            ortografia.append(columna)
    return ortografia

print("-------------------------")  
print("Ortografía de las columnas")
print("-------------------------")  
print(ortografia_columnas(df))
# Out:
# ['c:\\Users\\20927322707\\Desktop\\analizador_datasets\\Analizador', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\python312.zip', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\DLLs', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3', '', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib\\site-packages', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\20927322707\\AppData\\Local\\anaconda3\\Lib\\site-packages\\setuptools\\_vendor']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 8
#       4 print(sys.path)
#       7 import re
# ----> 8 from fuzzywuzzy import fuzz
#      11 def ortografia_columnas(df):
#      12     columnas = df.columns
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'

# %%
# Se crea un objeto de la clase CalidadDatos con los datos de interés
ruta_covid = "dataset ejemplos.xlsx"
datos_covid = CalidadDatos(ruta_covid)
# Out:
# C:\Users\jairoruiz\Documents\GitHub\leila_env\lib\site-packages\leila\calidad_datos.py:1307: UserWarning: Cargar archivos xlsx puede tomar demasiado tiempo, se aconseja fuertemente convertirlos a archivo csv, esto puede mejorar hasta 100x veces la velocidad de carga del archivo dataset ejemplos.xlsx
#   "Cargar archivos xlsx puede tomar demasiado tiempo, se aconseja "

# %% [markdown]
# #### 1. Tabla de resumen
# El método "resumen" calcula varias estadísticas que dan una primera impresión del conjunto de datos.
#
# Estas métricas incluyen el número de filas y columnas; número de columnas de distintos tipos; número de filas y columnas repetidas (duplicadas); columnas con muchos datos faltantes o extremos; peso del conjunto de datos

# %% [markdown]
# #### 2. Tipos de cada columna
# El método "TipoColumnas" calcula el tipo de cada columna de tres maneras diferentes.
#
# La primera es el tipo general de la columna en español. Indica si el tipo es numérico, texto, fecha, booleano u otro
#
# La segunda muestra el tipo general según el método dtypes de Python.
#
# La tercera manera muestra los tipos de cada celda de cada columna. Es decir, muestra la distribución de tipos de cada columna. El tipo que más aparece en esa columna se muestra en la variable "tipo_especifico_1" de la tabla de tipos y muestra el porcentaje. En caso de haber más de un tipo, se mostrará en las siguientes columnas "tipo_especifico_#"
#
# El ejemplo abajo muestra cómo el es código para generar los resultados de los tipos con el método "TipoCOlumnas". Los parámetros del método especifican qué tipo se quiere mostrar para las columnas (con las opciones True o False)

# %%
tipos = datos_covid.TipoColumnas(tipoGeneral=True, 
                                 tipoGeneralPython=True, 
                                 tipoEspecifico=True)
tipos
# Out:
#                             tipo_general tipo_general_python  \
# ID de caso                         Texto              string
# Fecha de notificación              Fecha      datetime64[ns]
# Código DIVIPOLA                    Texto              string
# Ciudad de ubicación                Texto              string
# Departamento o Distrito            Texto              string
# Atención                           Texto              string
# Edad                            Numérico               Int64
# Edad 2                          Numérico               Int64
# Edad meses                      Numérico               Int64
# Sexo                               Texto              string
# Tipo                               Texto              string
# Estado                             Texto              string
# País de procedencia                Texto              string
# Fecha de inicio de síntomas        Texto              string
# Fecha de muerte                    Fecha      datetime64[ns]
# Fecha diagnostico                  Fecha      datetime64[ns]
# Fecha recuperado                   Fecha      datetime64[ns]
# Fecha reporte web                  Fecha      datetime64[ns]
# Fecha de registro                  Fecha      datetime64[ns]
# Tipo recuperación                  Texto              string
# Codigo departamento                Texto              string
# Codigo pais                        Texto              string
# Pertenencia etnica                 Texto              string
# Nombre grupo etnico                Texto              string
# Diccionario                        Texto              string
#
#                                                              tipo_especifico_1  \
# ID de caso                                                       'str': 100.0%
# Fecha de notificación        'pandas._libs.tslibs.timestamps.Timestamp': 10...
# Código DIVIPOLA                                                  'str': 100.0%
# Ciudad de ubicación                                              'str': 100.0%
# Departamento o Distrito                                          'str': 100.0%
# Atención                                                         'str': 99.71%
# Edad                                                             'int': 100.0%
# Edad 2                                                           'int': 100.0%
# Edad meses                                                       'int': 100.0%
# Sexo                                                             'str': 100.0%
# Tipo                                                             'str': 100.0%
# Estado                                                           'str': 99.66%
# País de procedencia                      'pandas._libs.missing.NAType': 98.58%
# Fecha de inicio de síntomas                                      'str': 100.0%
# Fecha de muerte                  'pandas._libs.tslibs.nattype.NaTType': 95.38%
# Fecha diagnostico            'pandas._libs.tslibs.timestamps.Timestamp': 98...
# Fecha recuperado             'pandas._libs.tslibs.timestamps.Timestamp': 91...
# Fecha reporte web            'pandas._libs.tslibs.timestamps.Timestamp': 10...
# Fecha de registro            'pandas._libs.tslibs.timestamps.Timestamp': 10...
# Tipo recuperación                                                'str': 91.33%
# Codigo departamento                                              'str': 100.0%
# Codigo pais                              'pandas._libs.missing.NAType': 98.65%
# Pertenencia etnica                                               'str': 98.13%
# Nombre grupo etnico                      'pandas._libs.missing.NAType': 97.97%
# Diccionario                                                      'str': 100.0%
#
#                                                              tipo_especifico_2
# ID de caso
# Fecha de notificación
# Código DIVIPOLA
# Ciudad de ubicación
# Departamento o Distrito
# Atención                                  'pandas._libs.missing.NAType': 0.29%
# Edad
# Edad 2
# Edad meses
# Sexo
# Tipo
# Estado                                    'pandas._libs.missing.NAType': 0.34%
# País de procedencia                                               'str': 1.42%
# Fecha de inicio de síntomas
# Fecha de muerte              'pandas._libs.tslibs.timestamps.Timestamp': 4.62%
# Fecha diagnostico                 'pandas._libs.tslibs.nattype.NaTType': 1.59%
# Fecha recuperado                  'pandas._libs.tslibs.nattype.NaTType': 8.67%
# Fecha reporte web
# Fecha de registro
# Tipo recuperación                         'pandas._libs.missing.NAType': 8.67%
# Codigo departamento
# Codigo pais                                                       'str': 1.35%
# Pertenencia etnica                        'pandas._libs.missing.NAType': 1.87%
# Nombre grupo etnico                                               'str': 2.03%
# Diccionario

# %% [markdown]
# #### 3. Datos faltantes
#
# El método "ValoresFaltantes" permite calcular el número o porcentaje de valores faltantes de un conjunto de datos. Si el parámetro "numero" tiene asignado el valor True, se calcula el número de valores faltantes de cada columna. De lo contrario, si es False, se calcula el porcentaje.
#
# El ejemplo a continuación presenta los porcentajes de datos faltantes de cada columna del conjunto de datos de COVID-19

# %%
faltantes = datos_covid.ValoresFaltantes(numero = False)
faltantes
# Out:
# ID de caso                     0.000000
# Fecha de notificación          0.000000
# Código DIVIPOLA                0.000000
# Ciudad de ubicación            0.000000
# Departamento o Distrito        0.000000
# Atención                       0.002941
# Edad                           0.000000
# Edad 2                         0.000000
# Edad meses                     0.000000
# Sexo                           0.000000
# Tipo                           0.000000
# Estado                         0.003414
# País de procedencia            0.985766
# Fecha de inicio de síntomas    0.000000
# Fecha de muerte                0.953837
# Fecha diagnostico              0.015941
# Fecha recuperado               0.086701
# Fecha reporte web              0.000000
# Fecha de registro              0.000000
# Tipo recuperación              0.086701
# Codigo departamento            0.000000
# Codigo pais                    0.986512
# Pertenencia etnica             0.018745
# Nombre grupo etnico            0.979685
# Diccionario                    0.000000
# dtype: float64

# %% [markdown]
# #### 4. Datos duplicados
#
# El método "CantidadDuplicados" calcula el número o porcentaje de duplicados en el conjunto de datos.
#
# El ejemplo abajo calcula el número de duplicados para filas y columnas del conjunto de datos de COVID-19.

# %%
# Número de filas duplicadas. 
# Se escribe el parámetro eje = 0, para especificar fila
# Se escribe el parámetro numero = True, para especificar el número de duplicados (si es False se calcula el porcentaje)
filas_duplicadas = datos_covid.CantidadDuplicados(eje = 0, numero = True)

# Número de columnas duplicadas. 
# Se escribe el parámetro eje = 1, para especificar columna
# Se escribe el parámetro numero = False, para especificar el porcentaje de duplicados
columnas_duplicadas = datos_covid.CantidadDuplicados(eje = 1, numero = True)

print("Filas duplicadas: ", filas_duplicadas)
print("Columnas duplicadas: ", columnas_duplicadas)
# Out:
# Filas duplicadas:  1
# Columnas duplicadas:  2

# %% [markdown]
# #### 5. Emparejamiento de duplicados
# El método "EmparejamientoDuplicados" permite mostrar los nombres de filas o columnas que son exactamente iguales. El parámetro "col" especifica si se quieren emparejar los duplicados de filas al asignarlo a False. Para emparejar las columnas se escribe True.
#
# EL ejemplo abajo muestra los nombres de las filas duplicadas en cada columna de la tabla. Por ejemplo, la columna de la tabla "Filas iguales 1" muestra que las filas 1 y 2 son duplicadas.

# %%
emparejamiento_dupli_filas = datos_covid.EmparejamientoDuplicados(col = False)
emparejamiento_dupli_filas
# Out:
#    Filas iguales 1
# 0              267
# 1              269

# %% [markdown]
# EL ejemplo abajo muestra los nombres de las columnas duplicadas en cada columna de la tabla. Por ejemplo, la columna de la tabla "Columnas iguales 1" muestra que las columnas "Edad" y "Edad 2" son duplicadas

# %%
emparejamiento_dupli_cols = datos_covid.EmparejamientoDuplicados(col = True)
emparejamiento_dupli_cols
# Out:
#   Columnas iguales 1 Columnas iguales 2
# 0               Edad  Fecha reporte web
# 1             Edad 2  Fecha de registro

# %% [markdown]
# #### 6. Estadísticas descriptivas de variables numéricas
#
# El método DescripcionNumericas permite calcular estadísticas descriptivas para variables numéricas tales como el promedio, la desviación estándar, el mínimo, máximo, mediana (percentil 50), valores faltantes y extremos.
#
# El objetivo de estos cálculos es verificar si las variables del conjunto de datos contienen los valores esperados o si existen errores en la digitación de los valores
#
# El ejemplo abajo muestra las estadísticas descriptivas para las variables "Edad", "Edad_2" y "Edad meses"

# %%
descr_numericas = datos_covid.DescripcionNumericas()
descr_numericas
# Out:
#               count        mean         std  min    25%    50%    75%     max  \
# Edad        65616.0   39.175536   18.661339  0.0   26.0   36.0   52.0   104.0
# Edad 2      65616.0   39.175536   18.661339  0.0   26.0   36.0   52.0   104.0
# Edad meses  65616.0  476.099625  223.962309  1.0  318.0  443.0  626.0  1250.0
#
#             missing  outliers_total  outliers_altos  outliers_bajos
# Edad            0.0        0.002865        0.002865             0.0
# Edad 2          0.0        0.002865        0.002865             0.0
# Edad meses      0.0        0.004054        0.004054             0.0

# %% [markdown]
# Es posible calcular las estadísticas descriptivas para algunas variables únicamente. Esto se hace al asignar una lista con las variables de interés al parámetro "variales", como se muestra a continuación

# %%
descr_numericas = datos_covid.DescripcionNumericas(variables = ["Edad", "Edad meses"])
descr_numericas
# Out:
#               count        mean         std  min    25%    50%    75%     max  \
# Edad        65616.0   39.175536   18.661339  0.0   26.0   36.0   52.0   104.0
# Edad meses  65616.0  476.099625  223.962309  1.0  318.0  443.0  626.0  1250.0
#
#             missing  outliers_total  outliers_altos  outliers_bajos
# Edad            0.0        0.002865        0.002865             0.0
# Edad meses      0.0        0.004054        0.004054             0.0

# %% [markdown]
# #### 7. Estadísticas descriptivas de variables categóricas
# El método DescripcionCategoricas calcula la frecuencia, tanto en número como en porcentaje del total de filas, de los valores de las variables que se consideran numéricas.
#
# Las variables se consideran categóricas si contienen valores limitados. Por defecto, el máximo número de categorías es 30 y las categorías no pueden representar más del 50% del total de filas de la columna. Estos valores se pueden modificar en los parámetros "limite" y "categoriasMaximas" del método "DescripcionCategoricas".
#
# Es posible también especificar si las variables numéricas con pocos valores se quieren incluir en el análisis. Por ejemplo, variables que contienen únicamente los números 1 y 2. Para agregar las variables al análisis, se asigna el valor True al parámetro incluirNumericas (el cual está por defecto) y False si no se desean incluir.
#
# Por último, es posible agregar una lista limitada de variables al análisis, asignando una lista de Python con las variables al parámetro "variables"
#
# El ejemplo abajo muestra cómo se calculan las frecuencias de categorías de variables categóricas con los parámetros del método DescripcionCategoricas por defecto

# %%
descr_categoricas = datos_covid.DescripcionCategoricas(limite=0.5, 
                                                       categoriasMaximas=30, 
                                                       incluirNumericos=True, 
                                                       variables=None)
descr_categoricas
# Out:
#               Columna                             Valor  Frecuencia  \
# 0            Atención                        Recuperado     59927.0
# 1            Atención                         Fallecido      2914.0
# 2            Atención                          Hospital      2138.0
# 3            Atención                      Hospital UCI       438.0
# 4            Atención                              Casa         6.0
# 5            Atención                   Datos faltantes       193.0
# 6            Atención  Total categorías (incluye NA): 6         NaN
# 0                Sexo                                 M     35552.0
# 1                Sexo                                 F     30056.0
# 2                Sexo                                 f         6.0
# 3                Sexo                                 m         2.0
# 4                Sexo                   Datos faltantes         0.0
# 5                Sexo  Total categorías (incluye NA): 4         NaN
# 0                Tipo                        En estudio     50836.0
# 1                Tipo                       Relacionado     13847.0
# 2                Tipo                         Importado       933.0
# 3                Tipo                   Datos faltantes         0.0
# 4                Tipo  Total categorías (incluye NA): 3         NaN
# 0              Estado                              Leve     52084.0
# 1              Estado                      Asintomático      6811.0
# 2              Estado                          Moderado      3135.0
# 3              Estado                         Fallecido      2914.0
# 4              Estado                             Grave       448.0
# 5              Estado                   Datos faltantes       224.0
# 6              Estado  Total categorías (incluye NA): 6         NaN
# 0   Tipo recuperación                               PCR     35370.0
# 1   Tipo recuperación                            Tiempo     24557.0
# 2   Tipo recuperación                   Datos faltantes      5689.0
# 3   Tipo recuperación  Total categorías (incluye NA): 3         NaN
# 0  Pertenencia etnica                              Otro     57670.0
# 1  Pertenencia etnica                             Negro      5003.0
# 2  Pertenencia etnica                          Indígena      1333.0
# 3  Pertenencia etnica                               Rom       293.0
# 4  Pertenencia etnica                            Raizal        72.0
# 5  Pertenencia etnica                        Palenquero        15.0
# 6  Pertenencia etnica                   Datos faltantes      1230.0
# 7  Pertenencia etnica  Total categorías (incluye NA): 7         NaN
# 0         Diccionario                               {1}     32808.0
# 1         Diccionario                               {2}     32808.0
# 2         Diccionario                   Datos faltantes         0.0
# 3         Diccionario  Total categorías (incluye NA): 2         NaN
#
#    Porcentaje del total de filas
# 0                       0.913299
# 1                       0.044410
# 2                       0.032584
# 3                       0.006675
# 4                       0.000091
# 5                       0.002941
# 6                            NaN
# 0                       0.541819
# 1                       0.458059
# 2                       0.000091
# 3                       0.000030
# 4                       0.000000
# 5                            NaN
# 0                       0.774750
# 1                       0.211031
# 2                       0.014219
# 3                       0.000000
# 4                            NaN
# 0                       0.793770
# 1                       0.103801
# 2                       0.047778
# 3                       0.044410
# 4                       0.006828
# 5                       0.003414
# 6                            NaN
# 0                       0.539045
# 1                       0.374253
# 2                       0.086701
# 3                            NaN
# 0                       0.878901
# 1                       0.076247
# 2                       0.020315
# 3                       0.004465
# 4                       0.001097
# 5                       0.000229
# 6                       0.018745
# 7                            NaN
# 0                       0.500000
# 1                       0.500000
# 2                       0.000000
# 3                            NaN

# %% [markdown]
# #### 8. Peso de las variables en la memoria RAM
# Para calcular cuál es el peso de cada variable, se utiliza el método "Memoria", como se muestra en el ejemplo abajo. El parámetro "unidad" indica que se quiere calcular en Mega Bytes ("Mb") y el parámetro "col" indica que se calcula para cada variable. En caso de desear calcular el peso total del conjunto de datos, se asigna False al parámetro "col".

# %%
peso_memoria = datos_covid.Memoria(col=True, unidad="Mb")
peso_memoria
# Out:
# Index                          0.000122
# ID de caso                     0.500610
# Fecha de notificación          0.500610
# Código DIVIPOLA                0.500610
# Ciudad de ubicación            0.500610
# Departamento o Distrito        0.500610
# Atención                       0.500610
# Edad                           0.563187
# Edad 2                         0.563187
# Edad meses                     0.563187
# Sexo                           0.500610
# Tipo                           0.500610
# Estado                         0.500610
# País de procedencia            0.500610
# Fecha de inicio de síntomas    0.500610
# Fecha de muerte                0.500610
# Fecha diagnostico              0.500610
# Fecha recuperado               0.500610
# Fecha reporte web              0.500610
# Fecha de registro              0.500610
# Tipo recuperación              0.500610
# Codigo departamento            0.500610
# Codigo pais                    0.500610
# Pertenencia etnica             0.500610
# Nombre grupo etnico            0.500610
# Diccionario                    0.500610
# dtype: float64

# %% [markdown]
# #### 9 Correlación entre variables numéricas
#
# El método "CorrelacionNumericas" calcula una matriz de correlación entre las variables numéricas del conjunto de datos.
#
# El parámetro "metodo" especifica si se desea calcular las correlaciones con el método Pearson ("pearson"), Kendall ("kendall") o Spearman ("spearman")
#
# El ejemplo abajo muestra la matriz de correlación para variables numéricas del conjunto de datos de COVID-19

# %%
corr_numericas = datos_covid.CorrelacionNumericas(metodo="pearson", variables=None)
corr_numericas
# Out:
#               Edad  Edad 2  Edad meses
# Edad        1.0000  1.0000      0.9999
# Edad 2      1.0000  1.0000      0.9999
# Edad meses  0.9999  0.9999      1.0000

# %% [markdown]
# #### 10. Correlación de variables categóricas
# El método "CorrelacionCategoricas" calcula una matriz de correlación para variables categóricas. Contiene los mismos parámetros que se explicaron en la Sección 7, para definir variables categóricas, pero incluye también el parámetro "metodo". Este especifica si se quiere calcular la matriz con el método Cramer ("cramer") o con la metodología Phik ("phik"), de la librería Phik de Python.
#
# A continuación se calcula la matriz de correlación de variables categóricas para el conjunto de datos de COVID-19

# %%
corr_categoricas = datos_covid.CorrelacionCategoricas(metodo="phik")
corr_categoricas
# Out:
#                     Atención      Sexo      Tipo    Estado  Tipo recuperación  \
# Atención            1.000000  0.038193  0.195794  0.987038           0.941437
# Sexo                0.038193  1.000000  0.094794  0.041878           0.025933
# Tipo                0.195794  0.094794  1.000000  0.325888           0.320547
# Estado              0.987038  0.041878  0.325888  1.000000           0.917328
# Tipo recuperación   0.941437  0.025933  0.320547  0.917328           1.000000
# Pertenencia etnica  0.028540  0.000000  0.133658  0.067380           0.051298
# Diccionario         0.000000  0.000000  0.000000  0.004040           0.000000
#
#                     Pertenencia etnica  Diccionario
# Atención                      0.028540     0.000000
# Sexo                          0.000000     0.000000
# Tipo                          0.133658     0.000000
# Estado                        0.067380     0.004040
# Tipo recuperación             0.051298     0.000000
# Pertenencia etnica            1.000000     0.002036
# Diccionario                   0.002036     1.000000
